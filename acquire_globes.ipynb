# %% [markdown]
# ## Goal:
#
# I want to scrape information from https://www.goldenglobes.com/winners-nominees in order build a csv that includes specific categories for the last 25 years. The categories I will incluse are:
# - Best film - Drama
# - Best film - Comedy
# - Best actor - Drama
# - Best actor - Comdey
# - Best actress - Drama
# - Best actress - Comedy
# - Best supporting actor - any
# - Best supporting actress - any
# - Best director (maybe - not scraped)
# - Best screenplay (maybe - not scraped)
#
# This csv will consist of the award year, categories, and who won. I will add onto this csv once the 2020 awards air, to build the db for more data on predicting the Academy awards.

# %%
import warnings
warnings.filterwarnings("ignore")

from requests import get
from bs4 import BeautifulSoup
import os
import re
import pandas as pd
import numpy as np

# %% [markdown]
# ## Page 1 nominations
#
# Work to scrapre info from page 1

# %%
url = 'https://www.goldenglobes.com/winners-nominees/2019'
headers = {'User-Agent': 'Codeup Bayes Data Science'}
response = get(url, headers=headers)

# %%
print(response.text[:400])
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML+RDFa 1.0//EN"
#   "http://www.w3.org/MarkUp/DTD/xhtml-rdfa-1.dtd">
# <html class="no-js" lang="en" dir="ltr" prefix="og: http://ogp.me/ns# article: http://ogp.me/ns/article# book: http://ogp.me/ns/book# profile: http://ogp.me/ns/profile# video: http://ogp.me/ns/video# product: http://ogp.me/ns/product# content: http://purl.org/rss/1.0/modules/content/ dc: http:

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
soup.title
# Out:
# <title>Winners &amp; Nominees 2019 | Golden Globes</title>

# %%
# use this in function to make dictionary
soup.title.string
# Out:
# 'Winners & Nominees 2019 | Golden Globes'

# %%
for title in soup.title:
    print(title)
# Out:
# Winners & Nominees 2019 | Golden Globes

# %%
soup.title.text
# Out:
# 'Winners & Nominees 2019 | Golden Globes'

# %%
def get_year(url):
    headers = {'User-Agent':'Codeup Data Science Student'}
    response = get(url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    x = []
    for title in soup.title:
        x.append(title)
    return x

# %%
get_year('https://www.goldenglobes.com/winners-nominees/2019')
# Out:
# ['Winners & Nominees 2019 | Golden Globes']

# %%
soup.find('div', class_='view-content')
# Out:
# <div class="view-content">
# <div class="view-grouping"><h2 class="view-grouping-header"><a id="category-72" name="category-72"></a><div>Best Motion Picture - Drama</div></h2><div class="view-grouping-content"> <h3><a href="/winners-nominees/best-motion-picture-drama">See award category for all years</a></h3>
# <div class="views-row views-row-1 views-row-odd views-row-first">
# <div class="views-field views-field-nominee-photo winner"> <span class="field-content"><a href="/film/bohemian-rhapsody"><img alt="" class="img-responsive" src="https://www.goldenglobes.com/sites/default/files/styles/portrait_medium/public/gg/Bohemian%20Rhapsody.jpg?itok=aXKS1-0O" typeof="foaf:Image"/></a></span> </div>
# <div class="views-field views-field-field-nomination-is-winner"> <div class="field-content">Winner</div> </div>
# <div class="views-field views-field-nominee-title"> <div class="primary-nominee"><a href="/film/bohemian-rhapsody">Bohemian Rhapsody</a></div> </div>
# ...

# %% [markdown]
# ### Categories

# %%
cat = soup.find_all(class_='view-grouping-header')
cat
# Out:
# [<h2 class="view-grouping-header"><a id="category-72" name="category-72"></a><div>Best Motion Picture - Drama</div></h2>,
#  <h2 class="view-grouping-header"><a id="category-1886" name="category-1886"></a><div>Best Motion Picture - Musical or Comedy</div></h2>,
#  <h2 class="view-grouping-header"><a id="category-32" name="category-32"></a><div>Best Performance by an Actress in a Motion Picture - Drama</div></h2>,
#  <h2 class="view-grouping-header"><a id="category-17" name="category-17"></a><div>Best Performance by an Actor in a Motion Picture - Drama</div></h2>]

# %%
drama = cat[0]
drama.text
# Out:
# 'Best Motion Picture - Drama'

# %%
comedy = cat[1]
comedy.text
# Out:
# 'Best Motion Picture - Musical or Comedy'

# %%
actress_drama = cat[2]
actress_drama.text
# Out:
# 'Best Performance by an Actress in a Motion Picture - Drama'

# %%
actor_drama = cat[3]
actor_drama.text
# Out:
# 'Best Performance by an Actor in a Motion Picture - Drama'

# %%
for h2 in soup.find_all(class_='view-grouping-header'):
    print(h2.text)
# Out:
# Best Motion Picture - Drama
# Best Motion Picture - Musical or Comedy
# Best Performance by an Actress in a Motion Picture - Drama
# Best Performance by an Actor in a Motion Picture - Drama

# %%
def get_category():
    x = []
    for h2 in soup.find_all(class_='view-grouping-header'):
        x.append(h2.text)
    return x

# %%
get_category()
# Out:
# ['Best Motion Picture - Drama',
#  'Best Motion Picture - Musical or Comedy',
#  'Best Performance by an Actress in a Motion Picture - Drama',
#  'Best Performance by an Actor in a Motion Picture - Drama']

# %% [markdown]
# ### Nominees

# %%
nominee = soup.find_all(class_='view-grouping-content')
nominee
# Out:
# [<div class="view-grouping-content"> <h3><a href="/winners-nominees/best-motion-picture-drama">See award category for all years</a></h3>
#  <div class="views-row views-row-1 views-row-odd views-row-first">
#  <div class="views-field views-field-nominee-photo winner"> <span class="field-content"><a href="/film/bohemian-rhapsody"><img alt="" class="img-responsive" src="https://www.goldenglobes.com/sites/default/files/styles/portrait_medium/public/gg/Bohemian%20Rhapsody.jpg?itok=aXKS1-0O" typeof="foaf:Image"/></a></span> </div>
#  <div class="views-field views-field-field-nomination-is-winner"> <div class="field-content">Winner</div> </div>
#  <div class="views-field views-field-nominee-title"> <div class="primary-nominee"><a href="/film/bohemian-rhapsody">Bohemian Rhapsody</a></div> </div>
#  <div class="views-field views-field-edit-node"> <span class="field-content"></span> </div> </div>
#  <div class="views-row views-row-2 views-row-even">
# ...

# %%
n_drama = nominee[0].text
n_drama
# Out:
# ' See award category for all years\n\n  \n Winner \n Bohemian Rhapsody \n   \n\n  \n Nominee \n BlacKkKlansman \n   \n\n  \n Nominee \n If Beale Street Could Talk \n   \n\n  \n Nominee \n Star Is Born, A (2018) \n   \n\n  \n Nominee \n Black Panther \n   \n'

# %%
n_comedy = nominee[1].text
n_comedy
# Out:
# ' See award category for all years\n\n  \n Winner \n Green Book \n   \n\n  \n Nominee \n Crazy Rich Asians \n   \n\n  \n Nominee \n Favourite, The \n   \n\n  \n Nominee \n Mary Poppins Returns \n   \n\n  \n Nominee \n Vice \n   \n'

# %%
n_drama_actress = nominee[2].text
n_drama_actress
# Out:
# ' See award category for all years\n\n  \n Winner \n Glenn CloseWife, The \n   \n\n  \n Nominee \n Lady GagaStar Is Born, A (2018) \n   \n\n  \n Nominee \n Nicole KidmanDestroyer \n   \n\n  \n Nominee \n Melissa McCarthyCan You Ever Forgive Me? \n   \n\n  \n Nominee \n Rosamund PikePrivate War, A \n   \n'

# %%
n_drama_actor = nominee[3].text
n_drama_actor
# Out:
# " See award category for all years\n\n  \n Winner \n Rami MalekBohemian Rhapsody \n   \n\n  \n Nominee \n Bradley CooperStar Is Born, A (2018) \n   \n\n  \n Nominee \n Willem DafoeAt Eternity's Gate \n   \n\n  \n Nominee \n Lucas HedgesBoy Erased \n   \n\n  \n Nominee \n John David WashingtonBlacKkKlansman \n   \n"

# %%
for h2 in soup.find_all(class_='view-grouping-content'):
    print(re.sub(r'\s', ' ', h2.text))
# Out:
#  See award category for all years      Winner   Bohemian Rhapsody           Nominee   BlacKkKlansman           Nominee   If Beale Street Could Talk           Nominee   Star Is Born, A (2018)           Nominee   Black Panther
#  See award category for all years      Winner   Green Book           Nominee   Crazy Rich Asians           Nominee   Favourite, The           Nominee   Mary Poppins Returns           Nominee   Vice
#  See award category for all years      Winner   Glenn CloseWife, The           Nominee   Lady GagaStar Is Born, A (2018)           Nominee   Nicole KidmanDestroyer           Nominee   Melissa McCarthyCan You Ever Forgive Me?           Nominee   Rosamund PikePrivate War, A
#  See award category for all years      Winner   Rami MalekBohemian Rhapsody           Nominee   Bradley CooperStar Is Born, A (2018)           Nominee   Willem DafoeAt Eternity's Gate           Nominee   Lucas HedgesBoy Erased           Nominee   John David WashingtonBlacKkKlansman

# %%
for h2 in soup.find_all(class_='primary-nominee'):
    print(h2.text)
# Out:
# Bohemian Rhapsody
# Black Panther
# BlacKkKlansman
# If Beale Street Could Talk
# Star Is Born, A (2018)
# Green Book
# Vice
# Crazy Rich Asians
# Favourite, The
# Mary Poppins Returns
# Glenn Close
# Melissa McCarthy
# Rosamund Pike
# Lady Gaga
# Nicole Kidman
# Rami Malek
# Bradley Cooper
# Willem Dafoe
# Lucas Hedges
# John David Washington

# %%
def get_nominees():
    x = []
    for h2 in soup.find_all(class_='primary-nominee'):
        x.append(re.sub(r'\s', ' ', h2.text))
    return x

# %%
get_nominees()
# Out:
# ['Bohemian Rhapsody',
#  'Black Panther',
#  'BlacKkKlansman',
#  'If Beale Street Could Talk',
#  'Star Is Born, A (2018)',
#  'Green Book',
#  'Vice',
#  'Crazy Rich Asians',
#  'Favourite, The',
#  'Mary Poppins Returns',
#  'Glenn Close',
#  'Melissa McCarthy',
#  'Rosamund Pike',
#  'Lady Gaga',
#  'Nicole Kidman',
#  'Rami Malek',
#  'Bradley Cooper',
#  'Willem Dafoe',
#  'Lucas Hedges',
#  'John David Washington']

# %%
noms = get_nominees()
print(noms[3])
print(noms[0])
# Out:
#  See award category for all years      Winner   Rami MalekBohemian Rhapsody           Nominee   Bradley CooperStar Is Born, A (2018)           Nominee   Willem DafoeAt Eternity's Gate           Nominee   Lucas HedgesBoy Erased           Nominee   John David WashingtonBlacKkKlansman
#  See award category for all years      Winner   Bohemian Rhapsody           Nominee   BlacKkKlansman           Nominee   If Beale Street Could Talk           Nominee   Star Is Born, A (2018)           Nominee   Black Panther

# %%
def make_dict_from_page(url):
    headers = {'User-Agent':'Codeup Data Science Student'}
    response = get(url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    year = soup.title.string
    cat = get_category()
    nominee = get_nominees()
    return {'year': year,
            'category': cat,
            'nominees': nominee
    }

# %%
make_dict_from_page('https://www.goldenglobes.com/winners-nominees/2019')
# Out:
# {'year': 'Winners & Nominees 2019 | Golden Globes',
#  'category': ['Best Motion Picture - Drama',
#   'Best Motion Picture - Musical or Comedy',
#   'Best Performance by an Actress in a Motion Picture - Drama',
#   'Best Performance by an Actor in a Motion Picture - Drama'],
#  'nominees': ['Bohemian Rhapsody',
#   'Black Panther',
#   'BlacKkKlansman',
#   'If Beale Street Could Talk',
#   'Star Is Born, A (2018)',
#   'Green Book',
#   'Vice',
#   'Crazy Rich Asians',
#   'Favourite, The',
#   'Mary Poppins Returns',
#   'Glenn Close',
#   'Melissa McCarthy',
#   'Rosamund Pike',
#   'Lady Gaga',
#   'Nicole Kidman',
#   'Rami Malek',
#   'Bradley Cooper',
#   'Willem Dafoe',
#   'Lucas Hedges',
#   'John David Washington']}

# %% [markdown]
# ## Page 2 nominations

# %%
url = 'https://www.goldenglobes.com/winners-nominees/2019?page=1'
headers = {'User-Agent': 'Codeup Bayes Data Science'}
response = get(url, headers=headers)

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %% [markdown]
# ### Categories

# %%
cat_2 = soup.find_all(class_='view-grouping-header')
cat_2
# Out:
# [<h2 class="view-grouping-header"><a id="category-1889" name="category-1889"></a><div>Best Performance by an Actress in a Motion Picture - Musical or Comedy</div></h2>,
#  <h2 class="view-grouping-header"><a id="category-1890" name="category-1890"></a><div>Best Performance by an Actor in a Motion Picture - Musical or Comedy</div></h2>,
#  <h2 class="view-grouping-header"><a id="category-1891" name="category-1891"></a><div>Best Performance by an Actress in a Supporting Role in any Motion Picture</div></h2>,
#  <h2 class="view-grouping-header"><a id="category-1892" name="category-1892"></a><div>Best Performance by an Actor in a Supporting Role in any Motion Picture</div></h2>]

# %%
actress_comedy = cat_2[0]
actress_comedy.text
# Out:
# 'Best Performance by an Actress in a Motion Picture - Musical or Comedy'

# %%
actor_comedy = cat_2[1]
actor_comedy.text
# Out:
# 'Best Performance by an Actor in a Motion Picture - Musical or Comedy'

# %%
support_actress = cat_2[2]
support_actress.text
# Out:
# 'Best Performance by an Actress in a Supporting Role in any Motion Picture'

# %%
support_actor = cat_2[3]
support_actor.text
# Out:
# 'Best Performance by an Actor in a Supporting Role in any Motion Picture'

# %%
for h2 in soup.find_all(class_='view-grouping-header'):
    print(h2.text)
# Out:
# Best Performance by an Actress in a Motion Picture - Musical or Comedy
# Best Performance by an Actor in a Motion Picture - Musical or Comedy
# Best Performance by an Actress in a Supporting Role in any Motion Picture
# Best Performance by an Actor in a Supporting Role in any Motion Picture

# %% [markdown]
# ### Nominees

# %%
nominee = soup.find_all(class_='primary-nominee')
nominee
# Out:
# [<div class="primary-nominee"><a href="/film/bohemian-rhapsody">Bohemian Rhapsody</a></div>,
#  <div class="primary-nominee"><a href="/film/black-panther">Black Panther</a></div>,
#  <div class="primary-nominee"><a href="/film/blackkklansman">BlacKkKlansman</a></div>,
#  <div class="primary-nominee"><a href="/film/if-beale-street-could-talk">If Beale Street Could Talk</a></div>,
#  <div class="primary-nominee"><a href="/film/star-born-2018">Star Is Born, A (2018)</a></div>,
#  <div class="primary-nominee"><a href="/film/green-book">Green Book</a></div>,
#  <div class="primary-nominee"><a href="/film/vice">Vice</a></div>,
#  <div class="primary-nominee"><a href="/film/crazy-rich-asians">Crazy Rich Asians</a></div>,
#  <div class="primary-nominee"><a href="/film/favourite">Favourite, The</a></div>,
#  <div class="primary-nominee"><a href="/film/mary-poppins-returns">Mary Poppins Returns</a></div>,
#  <div class="primary-nominee"><a href="/person/glenn-close">Glenn Close</a></div>,
# ...

# %%
n_comedy_actress = nominee[0].text
n_comedy_actress
# Out:
# 'Bohemian Rhapsody'

# %%
n_comedy_actor = nominee[1].text
n_comedy_actor
# Out:
# 'Black Panther'

# %%
n_drama_actress = nominee[2].text
n_drama_actress
# Out:
# 'BlacKkKlansman'

# %%
n_drama_actor = nominee[3].text
n_drama_actor
# Out:
# 'If Beale Street Could Talk'

# %% [markdown]
# #### Make dictionary

# %%
def make_dict_from_page(url):
    headers = {'User-Agent':'Codeup Data Science Student'}
    response = get(url, headers=headers)
    year = soup.title.string
    cat = soup.find(class_='view-grouping-header').get_text()
    nominee = soup.find(class_='view-grouping-content').get_text()
    return {'year': year,
            'category': cat,
            'nominees': nominee
    }

# %%
make_dict_from_page('https://www.goldenglobes.com/winners-nominees/2019')
# Out:
# {'year': 'Winners & Nominees 2019 | Golden Globes',
#  'category': 'Best Motion Picture - Drama',
#  'nominees': ' See award category for all years\n\n  \n Winner \n Bohemian Rhapsody \n   \n\n  \n Nominee \n Black Panther \n   \n\n  \n Nominee \n BlacKkKlansman \n   \n\n  \n Nominee \n If Beale Street Could Talk \n   \n\n  \n Nominee \n Star Is Born, A (2018) \n   \n'}

# %% [markdown]
# ### Scrape urls

# %%
def get_nominations():
    urls = [
        "https://www.goldenglobes.com/winners-nominees/2019",
        "https://www.goldenglobes.com/winners-nominees/2019?page=1"
    ]
    x = []
    for url in urls:
        x.append(make_dict_from_page(url))
    return x

# %%
get_nominations()
# Out:
# [{'year': 'Winners & Nominees 2019 | Golden Globes',
#   'category': 'Best Motion Picture - Drama',
#   'nominees': ' See award category for all years\n\n  \n Winner \n Bohemian Rhapsody \n   \n\n  \n Nominee \n Black Panther \n   \n\n  \n Nominee \n BlacKkKlansman \n   \n\n  \n Nominee \n If Beale Street Could Talk \n   \n\n  \n Nominee \n Star Is Born, A (2018) \n   \n'},
#  {'year': 'Winners & Nominees 2019 | Golden Globes',
#   'category': 'Best Motion Picture - Drama',
#   'nominees': ' See award category for all years\n\n  \n Winner \n Bohemian Rhapsody \n   \n\n  \n Nominee \n Black Panther \n   \n\n  \n Nominee \n BlacKkKlansman \n   \n\n  \n Nominee \n If Beale Street Could Talk \n   \n\n  \n Nominee \n Star Is Born, A (2018) \n   \n'}]

# %% [markdown]
# ### Test scraping all urls

# %%
def get_year(url):
    headers = {'User-Agent':'Codeup Data Science Student'}
    response = get(url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    x = []
    for title in soup.title:
        x.append(title)
    return x

# %%
# get the category for each award
def get_category(url):
    headers = {'User-Agent':'Codeup Data Science Student'}
    response = get(url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    x = []
    for h2 in soup.find_all(class_='view-grouping-header'):
        x.append(h2.text)       
    return x

# %%
# get the nominees for awards
def get_nominees(url):
    headers = {'User-Agent':'Codeup Data Science Student'}
    response = get(url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    x = []
    for h2 in soup.find_all(class_='primary-nominee'):
        x.append(re.sub(r'\s', ' ', h2.text))
    return x

# %%
# make a dictionary out of categories and nominees
def make_dict_from_page(url):
    headers = {'User-Agent':'Codeup Data Science Student'}
    response = get(url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    year = get_year(url)
    cat = get_category(url)
    #nominee = get_nominees(url)
    return {'year': year,
            'category': cat,
            #'nominees': nominee
    }

# %%
def get_nominations():
    urls = [
        "https://www.goldenglobes.com/winners-nominees/2019",
        "https://www.goldenglobes.com/winners-nominees/2019?page=1"
    ]
    x = []
    for url in urls:
        x.append(make_dict_from_page(url))
        
    return x

# %%
testing = get_nominations()

# %%
testing
# Out:
# [{'year': ['Winners & Nominees 2019 | Golden Globes'],
#   'category': ['Best Motion Picture - Drama',
#    'Best Motion Picture - Musical or Comedy',
#    'Best Performance by an Actress in a Motion Picture - Drama',
#    'Best Performance by an Actor in a Motion Picture - Drama'],
#   'nominees': ['Bohemian Rhapsody',
#    'Black Panther',
#    'BlacKkKlansman',
#    'If Beale Street Could Talk',
#    'Star Is Born, A (2018)',
#    'Green Book',
#    'Favourite, The',
#    'Mary Poppins Returns',
#    'Vice',
#    'Crazy Rich Asians',
#    'Glenn Close',
#    'Lady Gaga',
#    'Nicole Kidman',
#    'Melissa McCarthy',
#    'Rosamund Pike',
#    'Rami Malek',
#    'Bradley Cooper',
#    'Willem Dafoe',
#    'Lucas Hedges',
#    'John David Washington']},
#  {'year': ['Winners & Nominees 2019 | Golden Globes'],
#   'category': ['Best Performance by an Actress in a Motion Picture - Musical or Comedy',
#    'Best Performance by an Actor in a Motion Picture - Musical or Comedy',
# ...

# %%
def get_nominations():
    urls = [
        "https://www.goldenglobes.com/winners-nominees/2019",
        "https://www.goldenglobes.com/winners-nominees/2019?page=1",
        "https://www.goldenglobes.com/winners-nominees/2018",
        "https://www.goldenglobes.com/winners-nominees/2018?page=1",
        "https://www.goldenglobes.com/winners-nominees/2017",
        "https://www.goldenglobes.com/winners-nominees/2017?page=1",
        "https://www.goldenglobes.com/winners-nominees/2016",
        "https://www.goldenglobes.com/winners-nominees/2016?page=1",
        "https://www.goldenglobes.com/winners-nominees/2015",
        "https://www.goldenglobes.com/winners-nominees/2015?page=1",
        "https://www.goldenglobes.com/winners-nominees/2014",
        "https://www.goldenglobes.com/winners-nominees/2014?page=1",
        "https://www.goldenglobes.com/winners-nominees/2013",
        "https://www.goldenglobes.com/winners-nominees/2013?page=1",
        "https://www.goldenglobes.com/winners-nominees/2012",
        "https://www.goldenglobes.com/winners-nominees/2012?page=1",
        "https://www.goldenglobes.com/winners-nominees/2011",
        "https://www.goldenglobes.com/winners-nominees/2011?page=1",
        "https://www.goldenglobes.com/winners-nominees/2010",
        "https://www.goldenglobes.com/winners-nominees/2010?page=1",
        "https://www.goldenglobes.com/winners-nominees/2009",
        "https://www.goldenglobes.com/winners-nominees/2009?page=1",
        "https://www.goldenglobes.com/winners-nominees/2008",
        "https://www.goldenglobes.com/winners-nominees/2008?page=1",
        "https://www.goldenglobes.com/winners-nominees/2007",
        "https://www.goldenglobes.com/winners-nominees/2007?page=1",
        "https://www.goldenglobes.com/winners-nominees/2006",
        "https://www.goldenglobes.com/winners-nominees/2006?page=1",
        "https://www.goldenglobes.com/winners-nominees/2005",
        "https://www.goldenglobes.com/winners-nominees/2005?page=1"
    ]
    x = []
    for url in urls:
        x.append(make_dict_from_page(url))
        
    #df = pd.DataFrame(x)
    #df.to_csv("golden_globes.csv")
    return x

# %%
test = get_nominations()
test
# Out:
# [{'year': ['Winners & Nominees 2019 | Golden Globes'],
#   'category': ['Best Motion Picture - Drama',
#    'Best Motion Picture - Musical or Comedy',
#    'Best Performance by an Actress in a Motion Picture - Drama',
#    'Best Performance by an Actor in a Motion Picture - Drama']},
#  {'year': ['Winners & Nominees 2019 | Golden Globes'],
#   'category': ['Best Performance by an Actress in a Motion Picture - Musical or Comedy',
#    'Best Performance by an Actor in a Motion Picture - Musical or Comedy',
#    'Best Performance by an Actress in a Supporting Role in any Motion Picture',
#    'Best Performance by an Actor in a Supporting Role in any Motion Picture']},
#  {'year': ['Winners & Nominees 2018 | Golden Globes'],
#   'category': ['Best Motion Picture - Drama',
#    'Best Motion Picture - Musical or Comedy',
#    'Best Performance by an Actress in a Motion Picture - Drama',
#    'Best Performance by an Actor in a Motion Picture - Drama']},
# ...

# %%
df = pd.DataFrame(test)

# %%
df
# Out:
#                                              category  \
# 0   [Best Motion Picture - Drama, Best Motion Pict...
# 1   [Best Performance by an Actress in a Motion Pi...
# 2   [Best Motion Picture - Drama, Best Motion Pict...
# 3   [Best Performance by an Actress in a Motion Pi...
# 4   [Best Motion Picture - Drama, Best Motion Pict...
# 5   [Best Performance by an Actress in a Motion Pi...
# 6   [Best Motion Picture - Drama, Best Motion Pict...
# 7   [Best Performance by an Actress in a Motion Pi...
# 8   [Best Motion Picture - Drama, Best Motion Pict...
# 9   [Best Performance by an Actress in a Motion Pi...
# 10  [Best Motion Picture - Drama, Best Motion Pict...
# 11  [Best Performance by an Actress in a Motion Pi...
# 12  [Best Motion Picture - Drama, Best Motion Pict...
# 13  [Best Performance by an Actress in a Motion Pi...
# 14  [Best Motion Picture - Drama, Best Motion Pict...
# 15  [Best Performance by an Actress in a Motion Pi...
# ...

# %%
#df = pd.DataFrame.from_dict(test, orient='index')

# %% [markdown]
# ### Create a pandas df

# %%
nine = make_dict_from_page("https://www.goldenglobes.com/winners-nominees/2019")
nine = pd.DataFrame.from_dict(nine, orient='index')
nine.T.head()
# Out:
#                                       year  \
# 0  Winners & Nominees 2019 | Golden Globes
# 1                                     None
# 2                                     None
# 3                                     None
#
#                                             category
# 0                        Best Motion Picture - Drama
# 1            Best Motion Picture - Musical or Comedy
# 2  Best Performance by an Actress in a Motion Pic...
# 3  Best Performance by an Actor in a Motion Pictu...

# %%
teen = make_dict_from_page("https://www.goldenglobes.com/winners-nominees/2019?page=1")
teen = pd.DataFrame.from_dict(teen, orient='index')
teen.T.head()
# Out:
#                                       year  \
# 0  Winners & Nominees 2019 | Golden Globes
# 1                                     None
# 2                                     None
# 3                                     None
#
#                                             category
# 0  Best Performance by an Actress in a Motion Pic...
# 1  Best Performance by an Actor in a Motion Pictu...
# 2  Best Performance by an Actress in a Supporting...
# 3  Best Performance by an Actor in a Supporting R...

# %%
nineteen = pd.concat([nine.T, teen.T], ignore_index=True)
nineteen.head()
# Out:
#                                       year  \
# 0  Winners & Nominees 2019 | Golden Globes
# 1                                     None
# 2                                     None
# 3                                     None
# 4  Winners & Nominees 2019 | Golden Globes
#
#                                             category
# 0                        Best Motion Picture - Drama
# 1            Best Motion Picture - Musical or Comedy
# 2  Best Performance by an Actress in a Motion Pic...
# 3  Best Performance by an Actor in a Motion Pictu...
# 4  Best Performance by an Actress in a Motion Pic...

# %%
a = make_dict_from_page("https://www.goldenglobes.com/winners-nominees/2019")

# %%
df = pd.DataFrame.from_dict(a, orient='index')
df.T
# Out:
#                                       year  \
# 0  Winners & Nominees 2019 | Golden Globes
# 1                                     None
# 2                                     None
# 3                                     None
#
#                                             category
# 0                        Best Motion Picture - Drama
# 1            Best Motion Picture - Musical or Comedy
# 2  Best Performance by an Actress in a Motion Pic...
# 3  Best Performance by an Actor in a Motion Pictu...

# %% [markdown]
# ### Rearrange DF - create the columns

# %%
x = get_category("https://www.goldenglobes.com/winners-nominees/2019")

# %%
df = pd.DataFrame.from_dict(x)
df = df.T

# %%
headers = df.iloc[0]
new_df  = pd.DataFrame(df.values[1:], columns=headers)

# %%
new_df
# Out:
# Empty DataFrame
# Columns: [Best Motion Picture - Drama, Best Motion Picture - Musical or Comedy, Best Performance by an Actress in a Motion Picture - Drama, Best Performance by an Actor in a Motion Picture - Drama]
# Index: []

# %%
b = get_category("https://www.goldenglobes.com/winners-nominees/2019?page=1")

# %%
df = pd.DataFrame.from_dict(b)
df = df.T

# %%
headers = df.iloc[0]
n_df  = pd.DataFrame(df.values[1:], columns=headers)

# %%
n_df
# Out:
# Empty DataFrame
# Columns: [Best Performance by an Actress in a Motion Picture - Musical or Comedy, Best Performance by an Actor in a Motion Picture - Musical or Comedy, Best Performance by an Actress in a Supporting Role in any Motion Picture, Best Performance by an Actor in a Supporting Role in any Motion Picture]
# Index: []

# %%
v = get_year("https://www.goldenglobes.com/winners-nominees/2019")

# %%
df = pd.DataFrame.from_dict(v)
df = df.T

# %%
headers = df.iloc[0]
year_df  = pd.DataFrame(df.values[1:], columns=headers)
year_df
# Out:
# Empty DataFrame
# Columns: [Winners & Nominees 2019 | Golden Globes]
# Index: []

# %%
df = pd.concat([new_df, n_df, year_df], sort=True)

# %%
df
# Out:
# Empty DataFrame
# Columns: [Best Motion Picture - Drama, Best Motion Picture - Musical or Comedy, Best Performance by an Actor in a Motion Picture - Drama, Best Performance by an Actor in a Motion Picture - Musical or Comedy, Best Performance by an Actor in a Supporting Role in any Motion Picture, Best Performance by an Actress in a Motion Picture - Drama, Best Performance by an Actress in a Motion Picture - Musical or Comedy, Best Performance by an Actress in a Supporting Role in any Motion Picture, Winners & Nominees 2019 | Golden Globes]
# Index: []

# %%
df['year'] = df['Winners & Nominees 2019 | Golden Globes']
df['best_drama'] = df['Best Motion Picture - Drama']
df['best_comedy'] = df['Best Motion Picture - Musical or Comedy']
df['best_actor_drama'] = df['Best Performance by an Actor in a Motion Picture - Drama']
df['best_actor_comedy'] = df['Best Performance by an Actor in a Motion Picture - Musical or Comedy']
df['best_supporting_actor'] = df['Best Performance by an Actress in a Motion Picture - Drama']
df['best_actress_drama'] = df['Best Performance by an Actress in a Motion Picture - Musical or Comedy']
df['best_actress_comedy'] = df['Best Performance by an Actor in a Supporting Role in any Motion Picture']
df['best_supporting_actress'] = df['Best Performance by an Actress in a Supporting Role in any Motion Picture']

# %%
df.drop(columns = ('Winners & Nominees 2019 | Golden Globes'), inplace=True)
df.drop(columns = ('Best Motion Picture - Drama'), inplace=True)
df.drop(columns = ('Best Motion Picture - Musical or Comedy'), inplace=True)
df.drop(columns = ('Best Performance by an Actor in a Motion Picture - Drama'), inplace=True)
df.drop(columns = ('Best Performance by an Actor in a Motion Picture - Musical or Comedy'), inplace=True)
df.drop(columns = ('Best Performance by an Actress in a Motion Picture - Drama'), inplace=True)
df.drop(columns = ('Best Performance by an Actress in a Motion Picture - Musical or Comedy'), inplace=True)
df.drop(columns = ('Best Performance by an Actor in a Supporting Role in any Motion Picture'), inplace=True)
df.drop(columns = ('Best Performance by an Actress in a Supporting Role in any Motion Picture'), inplace=True)

# %%
df
# Out:
# Empty DataFrame
# Columns: [year, best_drama, best_comedy, best_actor_drama, best_actor_comedy, best_supporting_actor, best_actress_drama, best_actress_comedy, best_supporting_actress]
# Index: []

# %% [markdown]
# ### Place Nominees

# %%
print(get_nominees("https://www.goldenglobes.com/winners-nominees/2019"))
print(get_nominees("https://www.goldenglobes.com/winners-nominees/2019?page=1"))
# Out:
# ['Bohemian Rhapsody', 'Black Panther', 'BlacKkKlansman', 'If Beale Street Could Talk', 'Star Is Born, A (2018)', 'Green Book', 'Favourite, The', 'Mary Poppins Returns', 'Vice', 'Crazy Rich Asians', 'Glenn Close', 'Lady Gaga', 'Nicole Kidman', 'Melissa McCarthy', 'Rosamund Pike', 'Rami Malek', 'Bradley Cooper', 'Willem Dafoe', 'Lucas Hedges', 'John David Washington']
# ['Olivia Colman', 'Charlize Theron', 'Constance Wu', 'Emily Blunt', 'Elsie Fisher', 'Christian Bale', 'Lin-Manuel Miranda', 'Viggo Mortensen', 'Robert Redford', 'John C. Reilly', 'Regina King', 'Rachel Weisz', 'Amy Adams', 'Claire Foy', 'Emma Stone', 'Mahershala Ali', 'Timothée Chalamet', 'Adam Driver', 'Richard E. Grant', 'Sam Rockwell']

# %%
drama = ['Bohemian Rhapsody','Black Panther','BlacKkKlansman','If Beale Street Could Talk','A Star Is Born']
comedy = ['Green Book', 'The Favorite', 'Marry Poppins Returns', 'Vice', 'Crazy Rich Asians']
actress_d = ['Glenn Close', 'Lady Gaga', 'Nicole Kidman', 'Melissa McCarthy', 'Rosamund Pike']
actor_d = ['Rami Malek', 'Bradley Cooper', 'Willem Dafoe', 'Lucas Hedges', 'John David Washington']
actress_c = ['Olivia Coleman', 'Emily Blunt', 'Elsie Fisher', 'Charlize Theron', 'Constance Wu']
actor_c = ['Christian Bale', 'Robert Redford', 'John C. Reilly', 'Lin-Manuel Miranda', 'Viggo Mortensen']
support_actress = ['Regina King', 'Amy Adams', 'Claire Foy', 'Emma Stone', 'Rachel Weisz']
support_actor = ['Mahershala Ali', 'Sam Rockwell', 'Timothée Chalamet', 'Adam Driver', 'Richard E. Grant']
year = ['2019', '2019', '2019', '2019', '2019']
win = [True, False, False, False, False]
df0 = df.assign(**{'year':year, 'best_drama':drama,'win':win, 'best_comedy':comedy, 'best_actress_drama':actress_d, 'best_actor_drama': actor_d, 'best_actress_comedy':actress_c, 'best_actor_comedy':actor_c, 'best_supporting_actress':support_actress, 'best_supporting_actor':support_actor})

# %%
df0
# Out:
#    year                  best_drama            best_comedy  \
# 0  2019           Bohemian Rhapsody             Green Book
# 1  2019               Black Panther           The Favorite
# 2  2019              BlacKkKlansman  Marry Poppins Returns
# 3  2019  If Beale Street Could Talk                   Vice
# 4  2019              A Star Is Born      Crazy Rich Asians
#
#         best_actor_drama   best_actor_comedy best_supporting_actor  \
# 0             Rami Malek      Christian Bale        Mahershala Ali
# 1         Bradley Cooper      Robert Redford          Sam Rockwell
# 2           Willem Dafoe      John C. Reilly     Timothée Chalamet
# 3           Lucas Hedges  Lin-Manuel Miranda           Adam Driver
# 4  John David Washington     Viggo Mortensen      Richard E. Grant
#
#   best_actress_drama best_actress_comedy best_supporting_actress    win
# 0        Glenn Close      Olivia Coleman             Regina King   True
# ...

# %%
#df.year.fillna(2019,inplace=True)

# %%
#df.year.astype(str)

# %%
print(get_nominees("https://www.goldenglobes.com/winners-nominees/2018"))
print(get_nominees("https://www.goldenglobes.com/winners-nominees/2018?page=1"))
# Out:
# ['Three Billboards Outside Ebbing, Missouri', 'Call Me By Your Name', 'Dunkirk', 'The Post', 'The Shape of Water', 'Lady Bird', 'Disaster Artist, The ', 'Get Out', 'The Greatest Showman', 'I, Tonya', 'Frances McDormand', 'Jessica Chastain', 'Sally Hawkins', 'Meryl Streep', 'Michelle Williams', 'Gary Oldman', 'Denzel Washington', 'Timothée Chalamet', 'Daniel Day-Lewis', 'Tom Hanks']
# ['Saoirse Ronan', 'Judi Dench', 'Helen Mirren', 'Margot Robbie', 'Emma Stone', 'James Franco', 'Steve Carell', 'Ansel Elgort', 'Hugh Jackman', 'Daniel Kaluuya', 'Allison Janney', 'Hong Chau', 'Laurie Metcalf', 'Octavia Spencer', 'Mary J. Blige', 'Sam Rockwell', 'Willem Dafoe', 'Armie Hammer', 'Richard Jenkins', 'Christopher Plummer']

# %%
drama = ['Three Billboards Outside Ebbing, Missouri', 'Call Me By Your Name', 'Dunkirk', 'The Post', 'The Shape of Water']
comedy = ['Lady Bird', 'The Disaster Artist', 'Get Out', 'The Greatest Showman', 'I, Tonya']
actress_d = ['Frances McDormand', 'Meryl Streep', 'Michelle Williams', 'Jessica Chastain', 'Sally Hawkins']
actor_d = ['Gary Oldman', 'Timothée Chalamet', 'Daniel Day-Lewis', 'Tom Hanks', 'Denzel Washington']
actress_c = ['Saoirse Ronan', 'Judi Dench', 'Helen Mirren', 'Margot Robbie', 'Emma Stone']
actor_c = ['James Franco', 'Steve Carell', 'Ansel Elgort', 'Hugh Jackman', 'Daniel Kaluuya']
support_actress = ['Allison Janney', 'Hong Chau', 'Laurie Metcalf', 'Octavia Spencer', 'Mary J. Blige']
support_actor = ['Sam Rockwell', 'Willem Dafoe', 'Armie Hammer', 'Richard Jenkins', 'Christopher Plummer']
year = ['2018', '2018', '2018', '2018', '2018']
win = [True, False, False, False, False]
df1 = df.assign(**{'year':year, 'best_drama':drama,'win':win, 'best_comedy':comedy, 'best_actress_drama':actress_d, 'best_actor_drama': actor_d, 'best_actress_comedy':actress_c, 'best_actor_comedy':actor_c, 'best_supporting_actress':support_actress, 'best_supporting_actor':support_actor})

# %%
df1
# Out:
#    year                                 best_drama           best_comedy  \
# 0  2018  Three Billboards Outside Ebbing, Missouri             Lady Bird
# 1  2018                       Call Me By Your Name   The Disaster Artist
# 2  2018                                    Dunkirk               Get Out
# 3  2018                                   The Post  The Greatest Showman
# 4  2018                         The Shape of Water              I, Tonya
#
#     best_actor_drama best_actor_comedy best_supporting_actor  \
# 0        Gary Oldman      James Franco          Sam Rockwell
# 1  Timothée Chalamet      Steve Carell          Willem Dafoe
# 2   Daniel Day-Lewis      Ansel Elgort          Armie Hammer
# 3          Tom Hanks      Hugh Jackman       Richard Jenkins
# 4  Denzel Washington    Daniel Kaluuya   Christopher Plummer
#
#   best_actress_drama best_actress_comedy best_supporting_actress    win
# 0  Frances McDormand       Saoirse Ronan          Allison Janney   True
# ...

# %%
print(get_nominees("https://www.goldenglobes.com/winners-nominees/2017"))
print(get_nominees("https://www.goldenglobes.com/winners-nominees/2017?page=1"))
# Out:
# ['Moonlight', 'Hell or High Water', 'Lion', 'Manchester by the Sea', 'Hacksaw Ridge', 'La La Land', '20th Century Women', 'Deadpool', 'Florence Foster Jenkins', 'Sing Street', 'Isabelle Huppert', 'Amy Adams', 'Jessica Chastain', 'Ruth Negga', 'Natalie Portman', 'Casey Affleck', 'Joel Edgerton', 'Andrew Garfield', 'Viggo Mortensen', 'Denzel Washington']
# ['Emma Stone', 'Annette Bening', 'Lily Collins', 'Hailee Steinfeld', 'Meryl Streep', 'Ryan Gosling', 'Jonah Hill', 'Ryan Reynolds', 'Colin Farrell', 'Hugh Grant', 'Viola Davis', 'Naomie Harris', 'Nicole Kidman', 'Octavia Spencer', 'Michelle Williams', 'Aaron Taylor-Johnson', 'Mahershala Ali', 'Jeff Bridges', 'Simon Helberg', 'Dev Patel']

# %%
drama = ['Moonlight', 'Hell or High Water', 'Lion', 'Manchester by the Sea', 'Hacksaw Ridge']
comedy = ['La La Land', '20th Century Women', 'Deadpool', 'Florence Foster Jenkins', 'Sing Street']
actress_d = ['Isabelle Huppert', 'Amy Adams', 'Jessica Chastain', 'Ruth Negga', 'Natalie Portman']
actor_d = ['Casey Affleck', 'Joel Edgerton', 'Andrew Garfield', 'Viggo Mortensen', 'Denzel Washington']
actress_c = ['Emma Stone', 'Annette Bening', 'Lily Collins', 'Hailee Steinfeld', 'Meryl Streep']
actor_c = ['Ryan Gosling', 'Jonah Hill', 'Ryan Reynolds', 'Colin Farrell', 'Hugh Grant']
support_actress = ['Viola Davis', 'Naomie Harris', 'Nicole Kidman', 'Octavia Spencer', 'Michelle Williams']
support_actor = ['Aaron Taylor-Johnson', 'Mahershala Ali', 'Jeff Bridges', 'Simon Helberg', 'Dev Patel']
year = ['2017', '2017', '2017', '2017', '2017']
win = [True, False, False, False, False]
df2 = df.assign(**{'year':year, 'best_drama':drama,'win':win, 'best_comedy':comedy, 'best_actress_drama':actress_d, 'best_actor_drama': actor_d, 'best_actress_comedy':actress_c, 'best_actor_comedy':actor_c, 'best_supporting_actress':support_actress, 'best_supporting_actor':support_actor})

# %%
df2
# Out:
#    year             best_drama              best_comedy   best_actor_drama  \
# 0  2017              Moonlight               La La Land      Casey Affleck
# 1  2017     Hell or High Water       20th Century Women      Joel Edgerton
# 2  2017                   Lion                 Deadpool    Andrew Garfield
# 3  2017  Manchester by the Sea  Florence Foster Jenkins    Viggo Mortensen
# 4  2017          Hacksaw Ridge              Sing Street  Denzel Washington
#
#   best_actor_comedy best_supporting_actor best_actress_drama  \
# 0      Ryan Gosling  Aaron Taylor-Johnson   Isabelle Huppert
# 1        Jonah Hill        Mahershala Ali          Amy Adams
# 2     Ryan Reynolds          Jeff Bridges   Jessica Chastain
# 3     Colin Farrell         Simon Helberg         Ruth Negga
# 4        Hugh Grant             Dev Patel    Natalie Portman
#
#   best_actress_comedy best_supporting_actress    win
# 0          Emma Stone             Viola Davis   True
# ...

# %%
print(get_nominees("https://www.goldenglobes.com/winners-nominees/2016"))
print(get_nominees("https://www.goldenglobes.com/winners-nominees/2016?page=1"))
# Out:
# ['The Revenant', 'Mad Max: Fury Road', 'Room', 'Spotlight', 'Carol', 'The Martian', 'Joy', 'Spy', 'Big Short, The', 'Trainwreck', 'Brie Larson', 'Saoirse Ronan', 'Cate Blanchett', 'Rooney Mara', 'Alicia Vikander', 'Leonardo DiCaprio', 'Will Smith', 'Michael Fassbender', 'Eddie Redmayne', 'Bryan Cranston']
# ['Jennifer Lawrence', 'Lily Tomlin', 'Melissa McCarthy', 'Maggie Smith', 'Amy Schumer', 'Matt Damon', 'Mark Ruffalo', 'Christian Bale', 'Steve Carell', 'Al Pacino', 'Kate Winslet', 'Alicia Vikander', 'Jennifer Jason Leigh', 'Helen Mirren', 'Jane Fonda', 'Sylvester Stallone', 'Idris Elba', 'Mark Rylance', 'Paul Dano', 'Michael Shannon']

# %%
drama = ['The Revenant', 'Mad Max: Fury Road', 'Room', 'Spotlight', 'Carol']
comedy = ['The Martian', 'Joy', 'Spy', 'The Big Short', 'Trainwreck']
actress_d = ['Brie Larson', 'Saoirse Ronan', 'Cate Blanchett', 'Rooney Mara', 'Alicia Vikander']
actor_d = ['Leonardo DiCaprio', 'Will Smith', 'Michael Fassbender', 'Eddie Redmayne', 'Bryan Cranston']
actress_c = ['Jennifer Lawrence', 'Lily Tomlin', 'Melissa McCarthy', 'Maggie Smith', 'Amy Schumer']
actor_c = ['Matt Damon', 'Steve Carell', 'Al Pacino', 'Mark Ruffalo', 'Christian Bale']
support_actress = ['Kate Winslet', 'Alicia Vikander', 'Jennifer Jason Leigh', 'Helen Mirren', 'Jane Fonda']
support_actor = ['Sylvester Stallone', 'Paul Dano', 'Michael Shannon', 'Idris Elba', 'Mark Rylance']
year = ['2016', '2016', '2016', '2016', '2016']
win = [True, False, False, False, False]
df3 = df.assign(**{'year':year, 'best_drama':drama,'win':win, 'best_comedy':comedy, 'best_actress_drama':actress_d, 'best_actor_drama': actor_d, 'best_actress_comedy':actress_c, 'best_actor_comedy':actor_c, 'best_supporting_actress':support_actress, 'best_supporting_actor':support_actor})

# %%
df3
# Out:
#    year          best_drama    best_comedy    best_actor_drama  \
# 0  2016        The Revenant    The Martian   Leonardo DiCaprio
# 1  2016  Mad Max: Fury Road            Joy          Will Smith
# 2  2016                Room            Spy  Michael Fassbender
# 3  2016           Spotlight  The Big Short      Eddie Redmayne
# 4  2016               Carol     Trainwreck      Bryan Cranston
#
#   best_actor_comedy best_supporting_actor best_actress_drama  \
# 0        Matt Damon    Sylvester Stallone        Brie Larson
# 1      Steve Carell             Paul Dano      Saoirse Ronan
# 2         Al Pacino       Michael Shannon     Cate Blanchett
# 3      Mark Ruffalo            Idris Elba        Rooney Mara
# 4    Christian Bale          Mark Rylance    Alicia Vikander
#
#   best_actress_comedy best_supporting_actress    win
# 0   Jennifer Lawrence            Kate Winslet   True
# 1         Lily Tomlin         Alicia Vikander  False
# 2    Melissa McCarthy    Jennifer Jason Leigh  False
# ...

# %%
print(get_nominees("https://www.goldenglobes.com/winners-nominees/2015"))
print(get_nominees("https://www.goldenglobes.com/winners-nominees/2015?page=1"))
# Out:
# ['Boyhood', 'The Imitation Game', 'Selma', 'Foxcatcher', 'The Theory of Everything', 'Grand Budapest Hotel, The', 'Into the Woods', 'St. Vincent', 'Pride', 'Birdman', 'Julianne Moore', 'Jennifer Aniston', 'Felicity Jones', 'Rosamund Pike', 'Reese Witherspoon', 'Eddie Redmayne', 'Steve Carell', 'Jake Gyllenhaal', 'Benedict Cumberbatch', 'David Oyelowo']
# ['Amy Adams', 'Julianne Moore', 'Quvenzhané Wallis', 'Emily Blunt', 'Helen Mirren', 'Michael Keaton', 'Ralph Fiennes', 'Christoph Waltz', 'Bill Murray', 'Joaquin Phoenix', 'Patricia Arquette', 'Jessica Chastain', 'Emma Stone', 'Keira Knightley', 'Meryl Streep', 'J.K. Simmons', 'Edward Norton', 'Mark Ruffalo', 'Robert Duvall', 'Ethan Hawke']

# %%
drama = ['Boyhood', 'Selma', 'Foxcatcher', 'The Theory of Everything', 'The Imitation Game']
comedy = ['The Grand Budapest Hotel', 'Into the Woods', 'St. Vincent', 'Pride', 'Birdman']
actress_d = ['Julianne Moore', 'Felicity Jones', 'Rosamund Pike', 'Reese Witherspoon', 'Jennifer Aniston']
actor_d = ['Eddie Redmayne', 'Benedict Cumberbatch', 'David Oyelowo', 'Steve Carell', 'Jake Gyllenhaal']
actress_c = ['Amy Adams', 'Julianne Moore', 'Quvenzhané Wallis', 'Emily Blunt', 'Helen Mirren']
actor_c = ['Michael Keaton', 'Ralph Fiennes', 'Christoph Waltz', 'Bill Murray', 'Joaquin Phoenix']
support_actress = ['Patricia Arquette', 'Jessica Chastain', 'Emma Stone', 'Keira Knightley', 'Meryl Streep']
support_actor = ['J.K. Simmons', 'Edward Norton', 'Mark Ruffalo', 'Robert Duvall', 'Ethan Hawke']
year = ['2015', '2015', '2015', '2015', '2015']
win = [True, False, False, False, False]
df4 = df.assign(**{'year':year, 'best_drama':drama,'win':win, 'best_comedy':comedy, 'best_actress_drama':actress_d, 'best_actor_drama': actor_d, 'best_actress_comedy':actress_c, 'best_actor_comedy':actor_c, 'best_supporting_actress':support_actress, 'best_supporting_actor':support_actor})

# %%
df4
# Out:
#    year                best_drama               best_comedy  \
# 0  2015                   Boyhood  The Grand Budapest Hotel
# 1  2015                     Selma            Into the Woods
# 2  2015                Foxcatcher               St. Vincent
# 3  2015  The Theory of Everything                     Pride
# 4  2015        The Imitation Game                   Birdman
#
#        best_actor_drama best_actor_comedy best_supporting_actor  \
# 0        Eddie Redmayne    Michael Keaton          J.K. Simmons
# 1  Benedict Cumberbatch     Ralph Fiennes         Edward Norton
# 2         David Oyelowo   Christoph Waltz          Mark Ruffalo
# 3          Steve Carell       Bill Murray         Robert Duvall
# 4       Jake Gyllenhaal   Joaquin Phoenix           Ethan Hawke
#
#   best_actress_drama best_actress_comedy best_supporting_actress    win
# 0     Julianne Moore           Amy Adams       Patricia Arquette   True
# 1     Felicity Jones      Julianne Moore        Jessica Chastain  False
# ...

# %%
print(get_nominees("https://www.goldenglobes.com/winners-nominees/2014"))
print(get_nominees("https://www.goldenglobes.com/winners-nominees/2014?page=1"))
# Out:
# ['12 Years a Slave', 'Gravity', 'Philomena', 'Rush', 'Captain Phillips', 'American Hustle', 'Nebraska', 'Inside Llewyn Davis', 'Her', 'Wolf of Wall Street, The', 'Cate Blanchett', 'Sandra Bullock', 'Judi Dench', 'Kate Winslet', 'Emma Thompson', 'Matthew McConaughey', 'Chiwetel Ejiofor', 'Tom Hanks', 'Idris Elba', 'Robert Redford']
# ['Amy Adams', 'Meryl Streep', 'Julie Delpy', 'Julia Louis-Dreyfus', 'Greta Gerwig', 'Leonardo DiCaprio', 'Christian Bale', 'Bruce Dern', 'Oscar Isaac', 'Joaquin Phoenix', 'Jennifer Lawrence', 'June Squibb', 'Julia Roberts', 'Sally Hawkins', "Lupita Nyong'o", 'Jared Leto', 'Michael Fassbender', 'Barkhad Abdi', 'Daniel Brühl', 'Bradley Cooper']

# %%
drama = ['12 Years a Slave', 'Captain Phillips', 'Gravity', 'Philomena', 'Rush']
comedy = ['American Hustle', 'The Wolf of Wall Street', 'Nebraska', 'Inside Llewyn Davis', 'Her']
actress_d = ['Cate Blanchett', 'Kate Winslet', 'Emma Thompson', 'Sandra Bullock', 'Judi Dench']
actor_d = ['Matthew McConaughey', 'Chiwetel Ejiofor', 'Tom Hanks', 'Idris Elba', 'Robert Redford']
actress_c = ['Amy Adams', 'Meryl Streep', 'Julie Delpy', 'Julia Louis-Dreyfus', 'Greta Gerwig']
actor_c = ['Leonardo DiCaprio', 'Bruce Dern', 'Oscar Isaac', 'Joaquin Phoenix', 'Christian Bale']
support_actress = ['Jennifer Lawrence', "Lupita Nyong'o", 'June Squibb', 'Julia Roberts', 'Sally Hawkins']
support_actor = ['Jared Leto', 'Barkhad Abdi', 'Daniel Brühl', 'Bradley Cooper', 'Michael Fassbender']
year = ['2014', '2014', '2014', '2014', '2014']
win = [True, False, False, False, False]
df5 = df.assign(**{'year':year, 'best_drama':drama,'win':win, 'best_comedy':comedy, 'best_actress_drama':actress_d, 'best_actor_drama': actor_d, 'best_actress_comedy':actress_c, 'best_actor_comedy':actor_c, 'best_supporting_actress':support_actress, 'best_supporting_actor':support_actor})

# %%
df5
# Out:
#    year        best_drama              best_comedy     best_actor_drama  \
# 0  2014  12 Years a Slave          American Hustle  Matthew McConaughey
# 1  2014  Captain Phillips  The Wolf of Wall Street     Chiwetel Ejiofor
# 2  2014           Gravity                 Nebraska            Tom Hanks
# 3  2014         Philomena      Inside Llewyn Davis           Idris Elba
# 4  2014              Rush                      Her       Robert Redford
#
#    best_actor_comedy best_supporting_actor best_actress_drama  \
# 0  Leonardo DiCaprio            Jared Leto     Cate Blanchett
# 1         Bruce Dern          Barkhad Abdi       Kate Winslet
# 2        Oscar Isaac          Daniel Brühl      Emma Thompson
# 3    Joaquin Phoenix        Bradley Cooper     Sandra Bullock
# 4     Christian Bale    Michael Fassbender         Judi Dench
#
#    best_actress_comedy best_supporting_actress    win
# 0            Amy Adams       Jennifer Lawrence   True
# ...

# %%
print(get_nominees("https://www.goldenglobes.com/winners-nominees/2013"))
print(get_nominees("https://www.goldenglobes.com/winners-nominees/2013?page=1"))
# Out:
# ['Argo', 'Django Unchained', 'Life of Pi', 'Lincoln', 'Zero Dark Thirty  ', 'Les Misérables', 'Silver Linings Playbook', 'Best Exotic Marigold Hotel, The', 'Moonrise Kingdom', 'Salmon Fishing in the Yemen', 'Jessica Chastain', 'Naomi Watts', 'Rachel Weisz', 'Marion Cotillard', 'Helen Mirren', 'Daniel Day-Lewis', 'Richard Gere', 'Joaquin Phoenix', 'Denzel Washington', 'John Hawkes']
# ['Jennifer Lawrence', 'Maggie Smith', 'Meryl Streep', 'Emily Blunt', 'Judi Dench', 'Hugh Jackman', 'Jack Black', 'Ewan McGregor', 'Bill Murray', 'Bradley Cooper', 'Anne Hathaway', 'Sally Field', 'Amy Adams', 'Helen Hunt', 'Nicole Kidman', 'Christoph Waltz', 'Alan Arkin', 'Leonardo DiCaprio', 'Tommy Lee Jones', 'Philip Seymour Hoffman']

# %%
drama = ['Argo', 'Life of Pi', 'Lincoln', 'Zero Dark Thirty  ', 'Django Unchained']
comedy = ['Les Misérables','The Best Exotic Marigold Hotel', 'Moonrise Kingdom', 'Salmon Fishing in the Yemen', 'Silver Linings Playbook']
actress_d = ['Jessica Chastain', 'Marion Cotillard', 'Helen Mirren', 'Naomi Watts', 'Rachel Weisz']
actor_d = ['Daniel Day-Lewis', 'Richard Gere', 'Joaquin Phoenix', 'Denzel Washington', 'John Hawkes']
actress_c = ['Jennifer Lawrence', 'Maggie Smith', 'Meryl Streep', 'Emily Blunt', 'Judi Dench']
actor_c = ['Hugh Jackman', 'Jack Black', 'Ewan McGregor', 'Bill Murray', 'Bradley Cooper']
support_actress = ['Anne Hathaway', 'Sally Field', 'Amy Adams', 'Helen Hunt', 'Nicole Kidman']
support_actor = ['Christoph Waltz', 'Alan Arkin', 'Leonardo DiCaprio', 'Tommy Lee Jones', 'Philip Seymour Hoffman']
year = ['2013', '2013', '2013', '2013', '2013']
win = [True, False, False, False, False]
df6 = df.assign(**{'year':year, 'best_drama':drama,'win':win, 'best_comedy':comedy, 'best_actress_drama':actress_d, 'best_actor_drama': actor_d, 'best_actress_comedy':actress_c, 'best_actor_comedy':actor_c, 'best_supporting_actress':support_actress, 'best_supporting_actor':support_actor})

# %%
df6
# Out:
#    year          best_drama                     best_comedy  \
# 0  2013                Argo                  Les Misérables
# 1  2013          Life of Pi  The Best Exotic Marigold Hotel
# 2  2013             Lincoln                Moonrise Kingdom
# 3  2013  Zero Dark Thirty       Salmon Fishing in the Yemen
# 4  2013    Django Unchained         Silver Linings Playbook
#
#     best_actor_drama best_actor_comedy   best_supporting_actor  \
# 0   Daniel Day-Lewis      Hugh Jackman         Christoph Waltz
# 1       Richard Gere        Jack Black              Alan Arkin
# 2    Joaquin Phoenix     Ewan McGregor       Leonardo DiCaprio
# 3  Denzel Washington       Bill Murray         Tommy Lee Jones
# 4        John Hawkes    Bradley Cooper  Philip Seymour Hoffman
#
#   best_actress_drama best_actress_comedy best_supporting_actress    win
# 0   Jessica Chastain   Jennifer Lawrence           Anne Hathaway   True
# 1   Marion Cotillard        Maggie Smith             Sally Field  False
# ...

# %%
print(get_nominees("https://www.goldenglobes.com/winners-nominees/2012"))
print(get_nominees("https://www.goldenglobes.com/winners-nominees/2012?page=1"))
# Out:
# ['Descendants, The', 'The Help', 'Hugo', 'Ides of March, The', 'Moneyball', 'War Horse', 'The Artist', '50/50', 'Bridesmaids', 'Midnight In Paris', 'My Week With Marilyn', 'Meryl Streep', 'Glenn Close', 'Viola Davis', 'Rooney Mara', 'Tilda Swinton', 'George Clooney', 'Leonardo DiCaprio', 'Michael Fassbender', 'Ryan Gosling', 'Brad Pitt']
# ['Michelle Williams', 'Jodie Foster', 'Charlize Theron', 'Kristen Wiig', 'Kate Winslet', 'Jean Dujardin', 'Brendan Gleeson', 'Joseph Gordon-Levitt', 'Ryan Gosling', 'Owen Wilson', 'Octavia Spencer', 'Jessica Chastain', 'Janet McTeer', 'Shailene Woodley', 'Bérénice Bejo', 'Christopher Plummer', 'Kenneth Branagh', 'Albert Brooks', 'Jonah Hill', 'Viggo Mortensen']

# %%
drama = ['The Descendants', 'Moneyball', 'War Horse', 'The Help', 'Hugo', 'The Ides of March']
comedy = ['The Artist', '50/50', 'Bridesmaids', 'Midnight In Paris', 'My Week With Marilyn', 'na']
actress_d = ['Meryl Streep', 'Glenn Close', 'Viola Davis', 'Rooney Mara', 'Tilda Swinton', 'na']
actor_d = ['George Clooney', 'Ryan Gosling', 'Brad Pitt', 'Leonardo DiCaprio', 'Michael Fassbender', 'na']
actress_c = ['Michelle Williams', 'Kate Winslet', 'Jodie Foster', 'Charlize Theron', 'Kristen Wiig', 'na']
actor_c = ['Jean Dujardin', 'Brendan Gleeson', 'Joseph Gordon-Levitt', 'Ryan Gosling', 'Owen Wilson', 'na']
support_actress = ['Octavia Spencer', 'Shailene Woodley', 'Bérénice Bejo', 'Jessica Chastain', 'Janet McTeer', 'na']
support_actor = ['Christopher Plummer', 'Kenneth Branagh', 'Albert Brooks', 'Jonah Hill', 'Viggo Mortensen', 'na']
year = ['2012', '2012', '2012', '2012', '2012', '2012']
win = [True, False, False, False, False, False]
df7 = df.assign(**{'year':year, 'best_drama':drama,'win':win, 'best_comedy':comedy, 'best_actress_drama':actress_d, 'best_actor_drama': actor_d, 'best_actress_comedy':actress_c, 'best_actor_comedy':actor_c, 'best_supporting_actress':support_actress, 'best_supporting_actor':support_actor})

# %%
df7
# Out:
#    year         best_drama           best_comedy    best_actor_drama  \
# 0  2012    The Descendants            The Artist      George Clooney
# 1  2012          Moneyball                 50/50        Ryan Gosling
# 2  2012          War Horse           Bridesmaids           Brad Pitt
# 3  2012           The Help     Midnight In Paris   Leonardo DiCaprio
# 4  2012               Hugo  My Week With Marilyn  Michael Fassbender
# 5  2012  The Ides of March                    na                  na
#
#       best_actor_comedy best_supporting_actor best_actress_drama  \
# 0         Jean Dujardin   Christopher Plummer       Meryl Streep
# 1       Brendan Gleeson       Kenneth Branagh        Glenn Close
# 2  Joseph Gordon-Levitt         Albert Brooks        Viola Davis
# 3          Ryan Gosling            Jonah Hill        Rooney Mara
# 4           Owen Wilson       Viggo Mortensen      Tilda Swinton
# 5                    na                    na                 na
#
# ...

# %%
print(get_nominees("https://www.goldenglobes.com/winners-nominees/2011"))
print(get_nominees("https://www.goldenglobes.com/winners-nominees/2011?page=1"))
# Out:
# ['The Social Network', 'Fighter, The', 'Inception', "The King's Speech", 'Black Swan', 'Kids Are All Right, The', 'Alice in Wonderland', 'Burlesque', 'Red', 'Tourist, The', 'Natalie Portman', 'Halle Berry', 'Nicole Kidman', 'Jennifer Lawrence', 'Michelle Williams', 'Colin Firth', 'Jesse Eisenberg', 'James Franco', 'Ryan Gosling', 'Mark Wahlberg']
# ['Annette Bening', 'Anne Hathaway', 'Angelina Jolie', 'Julianne Moore', 'Emma Stone', 'Paul Giamatti', 'Johnny Depp', 'Johnny Depp', 'Jake Gyllenhaal', 'Kevin Spacey', 'Melissa Leo', 'Helena Bonham Carter', 'Mila Kunis', 'Jacki Weaver', 'Amy Adams', 'Christian Bale', 'Michael Douglas', 'Andrew Garfield', 'Jeremy Renner', 'Geoffrey Rush']

# %%
drama = ['The Social Network', 'Black Swan', 'The Fighter', 'Inception', "The King's Speech"]
comedy = ['The Kids Are All Right', 'Burlesque', 'Red', 'The Tourist', 'Alice in Wonderland']
actress_d = ['Natalie Portman', 'Nicole Kidman', 'Jennifer Lawrence', 'Michelle Williams', 'Halle Berry']
actor_d = ['Colin Firth', 'Jesse Eisenberg', 'James Franco', 'Ryan Gosling', 'Mark Wahlberg']
actress_c = ['Annette Bening', 'Anne Hathaway', 'Angelina Jolie', 'Julianne Moore', 'Emma Stone']
actor_c = ['Paul Giamatti', 'Jake Gyllenhaal', 'Kevin Spacey', 'Johnny Depp', 'Johnny Depp']
support_actress = ['Melissa Leo', 'Amy Adams', 'Helena Bonham Carter', 'Mila Kunis', 'Jacki Weaver']
support_actor = ['Christian Bale', 'Geoffrey Rush', 'Michael Douglas', 'Andrew Garfield', 'Jeremy Renner']
year = ['2011', '2011', '2011', '2011', '2011']
win = [True, False, False, False, False]
df8 = df.assign(**{'year':year, 'best_drama':drama,'win':win, 'best_comedy':comedy, 'best_actress_drama':actress_d, 'best_actor_drama': actor_d, 'best_actress_comedy':actress_c, 'best_actor_comedy':actor_c, 'best_supporting_actress':support_actress, 'best_supporting_actor':support_actor})

# %%
df8
# Out:
#    year          best_drama             best_comedy best_actor_drama  \
# 0  2011  The Social Network  The Kids Are All Right      Colin Firth
# 1  2011          Black Swan               Burlesque  Jesse Eisenberg
# 2  2011         The Fighter                     Red     James Franco
# 3  2011           Inception             The Tourist     Ryan Gosling
# 4  2011   The King's Speech     Alice in Wonderland    Mark Wahlberg
#
#   best_actor_comedy best_supporting_actor best_actress_drama  \
# 0     Paul Giamatti        Christian Bale    Natalie Portman
# 1   Jake Gyllenhaal         Geoffrey Rush      Nicole Kidman
# 2      Kevin Spacey       Michael Douglas  Jennifer Lawrence
# 3       Johnny Depp       Andrew Garfield  Michelle Williams
# 4       Johnny Depp         Jeremy Renner        Halle Berry
#
#   best_actress_comedy best_supporting_actress    win
# 0      Annette Bening             Melissa Leo   True
# 1       Anne Hathaway               Amy Adams  False
# ...

# %%
print(get_nominees("https://www.goldenglobes.com/winners-nominees/2010"))
print(get_nominees("https://www.goldenglobes.com/winners-nominees/2010?page=1"))
# Out:
# ['Avatar', 'Up In The Air', 'Hurt Locker, The', 'Inglourious Basterds', 'Precious: Based On The Novel Push By Sapphire', 'Hangover, The', '(500) Days of Summer', "It's Complicated", 'Julie & Julia', 'Nine', 'Sandra Bullock', 'Emily Blunt', 'Helen Mirren', 'Carey Mulligan', 'Gabourey Sidibe', 'Jeff Bridges', 'Morgan Freeman', 'Tobey Maguire', 'George Clooney', 'Colin Firth']
# ['Meryl Streep', 'Meryl Streep', 'Sandra Bullock', 'Marion Cotillard', 'Julia Roberts', 'Robert Downey Jr.', 'Matt Damon', 'Daniel Day-Lewis', 'Joseph Gordon-Levitt', 'Michael Stuhlbarg', "Mo'Nique", 'Julianne Moore', 'Penélope Cruz', 'Vera Farmiga', 'Anna Kendrick', 'Christoph Waltz', 'Matt Damon', 'Woody Harrelson', 'Christopher Plummer', 'Stanley Tucci']

# %%
drama = ['Avatar', 'Up In The Air', 'The Hurt Locker', 'Inglourious Basterds', 'Precious: Based On The Novel Push By Sapphire']
comedy = ['The Hangover', '(500) Days of Summer', "It's Complicated", 'Julie & Julia', 'Nine']
actress_d = ['Sandra Bullock', 'Emily Blunt', 'Helen Mirren', 'Carey Mulligan', 'Gabourey Sidibe',]
actor_d = ['Jeff Bridges', 'Morgan Freeman', 'Tobey Maguire', 'George Clooney', 'Colin Firth']
actress_c = ['Meryl Streep', 'Sandra Bullock', 'Marion Cotillard', 'Julia Roberts', 'Meryl Streep']
actor_c = ['Robert Downey Jr.', 'Matt Damon', 'Daniel Day-Lewis', 'Joseph Gordon-Levitt', 'Michael Stuhlbarg']
support_actress = ["Mo'Nique", 'Vera Farmiga', 'Anna Kendrick', 'Julianne Moore', 'Penélope Cruz']
support_actor = ['Christoph Waltz', 'Matt Damon', 'Woody Harrelson', 'Christopher Plummer', 'Stanley Tucci']
year = ['2010', '2010', '2010', '2010', '2010']
win = [True, False, False, False, False]
df9 = df.assign(**{'year':year, 'best_drama':drama,'win':win,'best_comedy':comedy, 'best_actress_drama':actress_d, 'best_actor_drama': actor_d, 'best_actress_comedy':actress_c, 'best_actor_comedy':actor_c, 'best_supporting_actress':support_actress, 'best_supporting_actor':support_actor})

# %%
df9
# Out:
#    year                                     best_drama           best_comedy  \
# 0  2010                                         Avatar          The Hangover
# 1  2010                                  Up In The Air  (500) Days of Summer
# 2  2010                                The Hurt Locker      It's Complicated
# 3  2010                           Inglourious Basterds         Julie & Julia
# 4  2010  Precious: Based On The Novel Push By Sapphire                  Nine
#
#   best_actor_drama     best_actor_comedy best_supporting_actor  \
# 0     Jeff Bridges     Robert Downey Jr.       Christoph Waltz
# 1   Morgan Freeman            Matt Damon            Matt Damon
# 2    Tobey Maguire      Daniel Day-Lewis       Woody Harrelson
# 3   George Clooney  Joseph Gordon-Levitt   Christopher Plummer
# 4      Colin Firth     Michael Stuhlbarg         Stanley Tucci
#
#   best_actress_drama best_actress_comedy best_supporting_actress    win
# ...

# %%
print(get_nominees("https://www.goldenglobes.com/winners-nominees/2009"))
print(get_nominees("https://www.goldenglobes.com/winners-nominees/2009?page=1"))
# Out:
# ['Slumdog Millionaire', 'The Curious Case of Benjamin Button', 'Frost/Nixon', 'Reader, The', 'Revolutionary Road', 'Vicky Cristina Barcelona', 'Burn After Reading', 'Happy-Go-Lucky', 'In Bruges', 'Mamma Mia!', 'Kate Winslet', 'Kristin Scott Thomas', 'Meryl Streep', 'Anne Hathaway', 'Angelina Jolie', 'Mickey Rourke', 'Leonardo DiCaprio', 'Frank Langella', 'Sean Penn', 'Brad Pitt']
# ['Sally Hawkins', 'Meryl Streep', 'Emma Thompson', 'Rebecca Hall', 'Frances McDormand', 'Colin Farrell', 'Javier Bardem', 'James Franco', 'Brendan Gleeson', 'Dustin Hoffman', 'Kate Winslet', 'Amy Adams', 'Penélope Cruz', 'Viola Davis', 'Marisa Tomei', 'Heath Ledger', 'Tom Cruise', 'Robert Downey Jr.', 'Ralph Fiennes', 'Philip Seymour Hoffman']

# %%
drama = ['Slumdog Millionaire', 'The Curious Case of Benjamin Button', 'Frost/Nixon', 'The Reader', 'Revolutionary Road']
comedy = ['Vicky Cristina Barcelona', 'Burn After Reading', 'Happy-Go-Lucky', 'In Bruges', 'Mamma Mia!']
actress_d = ['Kate Winslet', 'Meryl Streep', 'Anne Hathaway', 'Angelina Jolie', 'Kristin Scott Thomas']
actor_d = ['Mickey Rourke', 'Brad Pitt', 'Leonardo DiCaprio', 'Frank Langella', 'Sean Penn']
actress_c = ['Sally Hawkins', 'Rebecca Hall', 'Frances McDormand', 'Meryl Streep', 'Emma Thompson']
actor_c = ['Colin Farrell', 'James Franco', 'Brendan Gleeson', 'Dustin Hoffman', 'Javier Bardem']
support_actress = ['Kate Winslet', 'Amy Adams', 'Penélope Cruz', 'Viola Davis', 'Marisa Tomei']
support_actor = ['Heath Ledger', 'Robert Downey Jr.', 'Ralph Fiennes', 'Philip Seymour Hoffman', 'Tom Cruise']
year = ['2009', '2009', '2009', '2009', '2009']
win = [True, False, False, False, False]
df10 = df.assign(**{'year':year, 'best_drama':drama, 'win':win,'best_comedy':comedy, 'best_actress_drama':actress_d, 'best_actor_drama': actor_d, 'best_actress_comedy':actress_c, 'best_actor_comedy':actor_c, 'best_supporting_actress':support_actress, 'best_supporting_actor':support_actor})

# %%
df10
# Out:
#    year                           best_drama               best_comedy  \
# 0  2009                  Slumdog Millionaire  Vicky Cristina Barcelona
# 1  2009  The Curious Case of Benjamin Button        Burn After Reading
# 2  2009                          Frost/Nixon            Happy-Go-Lucky
# 3  2009                           The Reader                 In Bruges
# 4  2009                   Revolutionary Road                Mamma Mia!
#
#     best_actor_drama best_actor_comedy   best_supporting_actor  \
# 0      Mickey Rourke     Colin Farrell            Heath Ledger
# 1          Brad Pitt      James Franco       Robert Downey Jr.
# 2  Leonardo DiCaprio   Brendan Gleeson           Ralph Fiennes
# 3     Frank Langella    Dustin Hoffman  Philip Seymour Hoffman
# 4          Sean Penn     Javier Bardem              Tom Cruise
#
#      best_actress_drama best_actress_comedy best_supporting_actress    win
# 0          Kate Winslet       Sally Hawkins            Kate Winslet   True
# ...

# %%
print(get_nominees("https://www.goldenglobes.com/winners-nominees/2008"))
print(get_nominees("https://www.goldenglobes.com/winners-nominees/2008?page=1"))
# Out:
# ['Atonement', 'There Will Be Blood', 'American Gangster', 'Eastern Promises', 'Great Debaters, The', 'Michael Clayton', 'No Country for Old Men', 'Sweeney Todd: The Demon Barber of Fleet Street', 'Across The Universe', "Charlie Wilson's War", 'Hairspray', 'Juno', 'Julie Christie', 'Jodie Foster', 'Angelina Jolie', 'Keira Knightley', 'Cate Blanchett', 'Daniel Day-Lewis', 'George Clooney', 'James McAvoy', 'Viggo Mortensen', 'Denzel Washington']
# ['Marion Cotillard', 'Ellen Page', 'Nikki Blonsky', 'Amy Adams', 'Helena Bonham Carter', 'Johnny Depp', 'Ryan Gosling', 'Tom Hanks', 'Philip Seymour Hoffman', 'John C. Reilly', 'Cate Blanchett', 'Tilda Swinton', 'Julia Roberts', 'Saoirse Ronan', 'Amy Ryan', 'Javier Bardem', 'Casey Affleck', 'Philip Seymour Hoffman', 'John Travolta', 'Tom Wilkinson']

# %%
drama = ['Atonement', 'Michael Clayton', 'No Country for Old Men', 'There Will Be Blood', 'American Gangster', 'Eastern Promises', 'The Great Debaters']
comedy = ['Sweeney Todd: The Demon Barber of Fleet Street', 'Across The Universe', "Charlie Wilson's War", 'Hairspray', 'Juno', 'na', 'na']
actress_d = ['Julie Christie', 'Cate Blanchett', 'Jodie Foster', 'Angelina Jolie', 'Keira Knightley', 'na', 'na']
actor_d = ['Daniel Day-Lewis', 'Denzel Washington', 'George Clooney', 'James McAvoy', 'Viggo Mortensen', 'na', 'na']
actress_c = ['Marion Cotillard', 'Nikki Blonsky', 'Amy Adams', 'Helena Bonham Carter', 'Ellen Page', 'na', 'na']
actor_c = ['Johnny Depp', 'Ryan Gosling', 'Tom Hanks', 'Philip Seymour Hoffman', 'John C. Reilly', 'na', 'na']
support_actress = ['Cate Blanchett', 'Julia Roberts', 'Saoirse Ronan', 'Amy Ryan', 'Tilda Swinton', 'na', 'na']
support_actor = ['Javier Bardem', 'Philip Seymour Hoffman', 'John Travolta', 'Tom Wilkinson', 'Casey Affleck', 'na', 'na']
year = ['2008', '2008', '2008', '2008', '2008', '2008', '2008']
win = [True, False, False, False, False, False, False]
df11 = df.assign(**{'year':year, 'best_drama':drama,'win':win, 'best_comedy':comedy, 'best_actress_drama':actress_d, 'best_actor_drama': actor_d, 'best_actress_comedy':actress_c, 'best_actor_comedy':actor_c, 'best_supporting_actress':support_actress, 'best_supporting_actor':support_actor})

# %%
df11
# Out:
#    year              best_drama  \
# 0  2008               Atonement
# 1  2008         Michael Clayton
# 2  2008  No Country for Old Men
# 3  2008     There Will Be Blood
# 4  2008       American Gangster
# 5  2008        Eastern Promises
# 6  2008      The Great Debaters
#
#                                       best_comedy   best_actor_drama  \
# 0  Sweeney Todd: The Demon Barber of Fleet Street   Daniel Day-Lewis
# 1                             Across The Universe  Denzel Washington
# 2                            Charlie Wilson's War     George Clooney
# 3                                       Hairspray       James McAvoy
# 4                                            Juno    Viggo Mortensen
# 5                                              na                 na
# 6                                              na                 na
#
#         best_actor_comedy   best_supporting_actor best_actress_drama  \
# 0             Johnny Depp           Javier Bardem     Julie Christie
# ...

# %%
print(get_nominees("https://www.goldenglobes.com/winners-nominees/2007"))
print(get_nominees("https://www.goldenglobes.com/winners-nominees/2007?page=1"))
# Out:
# ['Babel', 'Bobby', 'Departed, The', 'Little Children', 'Queen, The', 'Dreamgirls', 'Thank You For Smoking', 'Borat: Cultural Learnings Of America For Make Benefit Glorious Nation Of Kazakhstan', 'Devil Wears Prada, The', 'Little Miss Sunshine', 'Helen Mirren', 'Kate Winslet', 'Penélope Cruz', 'Judi Dench', 'Maggie Gyllenhaal', 'Forest Whitaker', 'Leonardo DiCaprio', 'Leonardo DiCaprio', "Peter O'Toole", 'Will Smith']
# ['Meryl Streep', 'Annette Bening', 'Toni Collette', 'Beyoncé', 'Renée Zellweger', 'Sacha Baron Cohen', 'Chiwetel Ejiofor', 'Will Ferrell', 'Johnny Depp', 'Aaron Eckhart', 'Jennifer Hudson', 'Adriana Barraza', 'Cate Blanchett', 'Emily Blunt', 'Rinko Kikuchi', 'Eddie Murphy', 'Mark Wahlberg', 'Ben Affleck', 'Jack Nicholson', 'Brad Pitt']

# %%
drama = ['Babel', 'Bobby', 'The Departed', 'Little Children', 'The Queen']
comedy = ['Dreamgirls', 'Borat: Cultural Learnings Of America For Make Benefit Glorious Nation Of Kazakhstan', 'The Devil Wears Prada', 'Little Miss Sunshine', 'Thank You For Smoking']
actress_d = ['Helen Mirren', 'Penélope Cruz', 'Judi Dench', 'Maggie Gyllenhaal', 'Kate Winslet']
actor_d = ['Forest Whitaker', 'Leonardo DiCaprio', 'Leonardo DiCaprio', "Peter O'Toole", 'Will Smith']
actress_c = ['Meryl Streep', 'Annette Bening', 'Toni Collette', 'Beyoncé', 'Renée Zellweger']
actor_c = ['Sacha Baron Cohen', 'Chiwetel Ejiofor', 'Will Ferrell', 'Johnny Depp', 'Aaron Eckhart']
support_actress = ['Jennifer Hudson', 'Adriana Barraza', 'Cate Blanchett', 'Emily Blunt', 'Rinko Kikuchi']
support_actor = ['Eddie Murphy', 'Mark Wahlberg', 'Ben Affleck', 'Jack Nicholson', 'Brad Pitt']
year = ['2007', '2007', '2007', '2007', '2007']
win = [True, False, False, False, False]
df12 = df.assign(**{'year':year, 'best_drama':drama,'win':win, 'best_comedy':comedy, 'best_actress_drama':actress_d, 'best_actor_drama': actor_d, 'best_actress_comedy':actress_c, 'best_actor_comedy':actor_c, 'best_supporting_actress':support_actress, 'best_supporting_actor':support_actor})

# %%
df12
# Out:
#    year       best_drama                                        best_comedy  \
# 0  2007            Babel                                         Dreamgirls
# 1  2007            Bobby  Borat: Cultural Learnings Of America For Make ...
# 2  2007     The Departed                              The Devil Wears Prada
# 3  2007  Little Children                               Little Miss Sunshine
# 4  2007        The Queen                              Thank You For Smoking
#
#     best_actor_drama  best_actor_comedy best_supporting_actor  \
# 0    Forest Whitaker  Sacha Baron Cohen          Eddie Murphy
# 1  Leonardo DiCaprio   Chiwetel Ejiofor         Mark Wahlberg
# 2  Leonardo DiCaprio       Will Ferrell           Ben Affleck
# 3      Peter O'Toole        Johnny Depp        Jack Nicholson
# 4         Will Smith      Aaron Eckhart             Brad Pitt
#
#   best_actress_drama best_actress_comedy best_supporting_actress    win
# ...

# %%
print(get_nominees("https://www.goldenglobes.com/winners-nominees/2006"))
print(get_nominees("https://www.goldenglobes.com/winners-nominees/2006?page=1"))
# Out:
# ['Brokeback Mountain', 'Match Point', 'Constant Gardener, The', 'Good Night, and Good Luck', 'A History of Violence', 'Walk The Line', 'Mrs. Henderson Presents', 'Pride & Prejudice', 'The Producers', 'Squid and the Whale, The', 'Felicity Huffman', 'Maria Bello', 'Gwyneth Paltrow', 'Charlize Theron', 'Ziyi Zhang', 'Philip Seymour Hoffman', 'Heath Ledger', 'David Strathairn', 'Russell Crowe', 'Terrence Howard']
# ['Reese Witherspoon', 'Judi Dench', 'Keira Knightley', 'Laura Linney', 'Sarah Jessica Parker', 'Joaquin Phoenix', 'Nathan Lane', 'Cillian Murphy', 'Pierce Brosnan', 'Jeff Daniels', 'Johnny Depp', 'Rachel Weisz', 'Scarlett Johansson', 'Shirley MacLaine', 'Frances McDormand', 'Michelle Williams', 'George Clooney', 'Paul Giamatti', 'Bob Hoskins', 'Matt Dillon', 'Will Ferrell']

# %%
drama = ['Brokeback Mountain', 'The Constant Gardener', 'Good Night, and Good Luck', 'A History of Violence', 'Match Point', 'na']
comedy = ['Walk The Line', 'Pride & Prejudice', 'The Producers', 'The Squid and the Whale', 'Mrs. Henderson Presents', 'na']
actress_d = ['Felicity Huffman', 'Gwyneth Paltrow', 'Charlize Theron', 'Ziyi Zhang', 'Maria Bello', 'na']
actor_d = ['Philip Seymour Hoffman', 'Russell Crowe', 'Terrence Howard', 'Heath Ledger', 'David Strathairn', 'na']
actress_c = ['Reese Witherspoon', 'Judi Dench', 'Keira Knightley', 'Laura Linney', 'Sarah Jessica Parker', 'na']
actor_c = ['Joaquin Phoenix', 'Pierce Brosnan', 'Jeff Daniels', 'Johnny Depp', 'Nathan Lane', 'Cillian Murphy']
support_actress = ['Rachel Weisz', 'Scarlett Johansson', 'Shirley MacLaine', 'Frances McDormand', 'Michelle Williams', 'na']
support_actor = ['George Clooney', 'Matt Dillon', 'Will Ferrell', 'Paul Giamatti', 'Bob Hoskins', 'na']
year = ['2006', '2006', '2006', '2006', '2006', '2006']
win = [True, False, False, False, False, False]
df13 = df.assign(**{'year':year, 'best_drama':drama,'win':win, 'best_comedy':comedy, 'best_actress_drama':actress_d, 'best_actor_drama': actor_d, 'best_actress_comedy':actress_c, 'best_actor_comedy':actor_c, 'best_supporting_actress':support_actress, 'best_supporting_actor':support_actor})

# %%
df13
# Out:
#    year                 best_drama              best_comedy  \
# 0  2006         Brokeback Mountain            Walk The Line
# 1  2006      The Constant Gardener        Pride & Prejudice
# 2  2006  Good Night, and Good Luck            The Producers
# 3  2006      A History of Violence  The Squid and the Whale
# 4  2006                Match Point  Mrs. Henderson Presents
# 5  2006                         na                       na
#
#          best_actor_drama best_actor_comedy best_supporting_actor  \
# 0  Philip Seymour Hoffman   Joaquin Phoenix        George Clooney
# 1           Russell Crowe    Pierce Brosnan           Matt Dillon
# 2         Terrence Howard      Jeff Daniels          Will Ferrell
# 3            Heath Ledger       Johnny Depp         Paul Giamatti
# 4        David Strathairn       Nathan Lane           Bob Hoskins
# 5                      na    Cillian Murphy                    na
#
#   best_actress_drama   best_actress_comedy best_supporting_actress    win
# ...

# %%
print(get_nominees("https://www.goldenglobes.com/winners-nominees/2005"))
print(get_nominees("https://www.goldenglobes.com/winners-nominees/2005?page=1"))
# Out:
# ['The Aviator', 'Kinsey', 'Million Dollar Baby', 'Closer', 'Finding Neverland', 'Hotel Rwanda', 'Sideways', 'Eternal Sunshine of The Spotless Mind', 'Incredibles, The', 'Ray', 'The Phantom of the Opera', 'Hilary Swank', 'Scarlett Johansson', 'Nicole Kidman', 'Imelda Staunton', 'Uma Thurman', 'Leonardo DiCaprio', 'Liam Neeson', 'Javier Bardem', 'Don Cheadle', 'Johnny Depp']
# ['Annette Bening', 'Emmy Rossum', 'Ashley Judd', 'Renée Zellweger', 'Kate Winslet', 'Jamie Foxx', 'Jim Carrey', 'Paul Giamatti', 'Kevin Kline', 'Kevin Spacey', 'Natalie Portman', 'Cate Blanchett', 'Laura Linney', 'Virginia Madsen', 'Meryl Streep', 'Clive Owen', 'David Carradine', 'Thomas Haden Church', 'Jamie Foxx', 'Morgan Freeman']

# %%
drama = ['The Aviator', 'Closer', 'Finding Neverland', 'Hotel Rwanda', 'Kinsey', 'Million Dollar Baby']
comedy = ['Sideways', 'Eternal Sunshine of The Spotless Mind', 'The Incredibles', 'Ray', 'The Phantom of the Opera', 'na']
actress_d = ['Hilary Swank', 'Scarlett Johansson', 'Nicole Kidman', 'Imelda Staunton', 'Uma Thurman', 'na']
actor_d = ['Leonardo DiCaprio', 'Javier Bardem', 'Don Cheadle', 'Johnny Depp', 'Liam Neeson', 'na']
actress_c = ['Annette Bening', 'Emmy Rossum', 'Ashley Judd', 'Renée Zellweger', 'Kate Winslet', 'na']
actor_c = ['Jamie Foxx', 'Jim Carrey', 'Paul Giamatti', 'Kevin Kline', 'Kevin Spacey', 'na']
support_actress = ['Natalie Portman', 'Cate Blanchett', 'Laura Linney', 'Virginia Madsen', 'Meryl Streep', 'na']
support_actor = ['Clive Owen', 'David Carradine', 'Thomas Haden Church', 'Jamie Foxx', 'Morgan Freeman', 'na']
year = ['2005', '2005', '2005', '2005', '2005', '2005']
win = [True, False, False, False, False, False]
df14 = df.assign(**{'year':year, 'best_drama':drama, 'win':win,'best_comedy':comedy, 'best_actress_drama':actress_d, 'best_actor_drama': actor_d, 'best_actress_comedy':actress_c, 'best_actor_comedy':actor_c, 'best_supporting_actress':support_actress, 'best_supporting_actor':support_actor})

# %%
df14
# Out:
#    year           best_drama                            best_comedy  \
# 0  2005          The Aviator                               Sideways
# 1  2005               Closer  Eternal Sunshine of The Spotless Mind
# 2  2005    Finding Neverland                        The Incredibles
# 3  2005         Hotel Rwanda                                    Ray
# 4  2005               Kinsey               The Phantom of the Opera
# 5  2005  Million Dollar Baby                                     na
#
#     best_actor_drama best_actor_comedy best_supporting_actor  \
# 0  Leonardo DiCaprio        Jamie Foxx            Clive Owen
# 1      Javier Bardem        Jim Carrey       David Carradine
# 2        Don Cheadle     Paul Giamatti   Thomas Haden Church
# 3        Johnny Depp       Kevin Kline            Jamie Foxx
# 4        Liam Neeson      Kevin Spacey        Morgan Freeman
# 5                 na                na                    na
#
# ...

# %%
print(get_nominees("https://www.goldenglobes.com/winners-nominees/2004"))
print(get_nominees("https://www.goldenglobes.com/winners-nominees/2004?page=1"))
# Out:
# ['The Lord of the Rings: The Return of the King', 'Cold Mountain', 'Master and Commander: The Far Side of the World', 'Mystic River', 'Seabiscuit', 'Lost in Translation', 'Bend It Like Beckham', 'Big Fish', 'Finding Nemo', 'Love Actually', 'Charlize Theron', 'Cate Blanchett', 'Scarlett Johansson', 'Nicole Kidman', 'Uma Thurman', 'Evan Rachel Wood', 'Sean Penn', 'Russell Crowe', 'Tom Cruise', 'Ben Kingsley', 'Jude Law']
# ['Diane Keaton', 'Jamie Lee Curtis', 'Scarlett Johansson', 'Diane Lane', 'Helen Mirren', 'Bill Murray', 'Billy Bob Thornton', 'Jack Black', 'Johnny Depp', 'Jack Nicholson', 'Renée Zellweger', 'Patricia Clarkson', 'Hope Davis', 'Holly Hunter', 'Maria Bello', 'Tim Robbins', 'Ken Watanabe', 'Alec Baldwin', 'Albert Finney', 'William H. Macy', 'Peter Sarsgaard']

# %%
drama = ['The Lord of the Rings: The Return of the King', 'Cold Mountain', 'Master and Commander: The Far Side of the World', 'Mystic River', 'Seabiscuit', 'na']
comedy = ['Lost in Translation', 'Bend It Like Beckham', 'Big Fish', 'Finding Nemo', 'Love Actually', 'na']
actress_d = ['Charlize Theron', 'Cate Blanchett', 'Scarlett Johansson', 'Nicole Kidman', 'Uma Thurman', 'Evan Rachel Wood']
actor_d = ['Sean Penn', 'Russell Crowe', 'Tom Cruise', 'Ben Kingsley', 'Jude Law', 'na']
actress_c = ['Diane Keaton', 'Jamie Lee Curtis', 'Scarlett Johansson', 'Diane Lane', 'Helen Mirren', 'na']
actor_c = ['Bill Murray', 'Billy Bob Thornton', 'Jack Black', 'Johnny Depp', 'Jack Nicholson', 'na']
support_actress = ['Renée Zellweger', 'Patricia Clarkson', 'Hope Davis', 'Holly Hunter', 'Maria Bello', 'na']
support_actor = ['Tim Robbins', 'Ken Watanabe', 'Alec Baldwin', 'Albert Finney', 'William H. Macy', 'Peter Sarsgaard']
year = ['2004', '2004', '2004', '2004', '2004', '2004']
win = [True, False, False, False, False, False]
df15 = df.assign(**{'year':year, 'best_drama':drama, 'win':win,'best_comedy':comedy, 'best_actress_drama':actress_d, 'best_actor_drama': actor_d, 'best_actress_comedy':actress_c, 'best_actor_comedy':actor_c, 'best_supporting_actress':support_actress, 'best_supporting_actor':support_actor})

# %%
df15
# Out:
#    year                                       best_drama  \
# 0  2004    The Lord of the Rings: The Return of the King
# 1  2004                                    Cold Mountain
# 2  2004  Master and Commander: The Far Side of the World
# 3  2004                                     Mystic River
# 4  2004                                       Seabiscuit
# 5  2004                                               na
#
#             best_comedy best_actor_drama   best_actor_comedy  \
# 0   Lost in Translation        Sean Penn         Bill Murray
# 1  Bend It Like Beckham    Russell Crowe  Billy Bob Thornton
# 2              Big Fish       Tom Cruise          Jack Black
# 3          Finding Nemo     Ben Kingsley         Johnny Depp
# 4         Love Actually         Jude Law      Jack Nicholson
# 5                    na               na                  na
#
#   best_supporting_actor  best_actress_drama best_actress_comedy  \
# 0           Tim Robbins     Charlize Theron        Diane Keaton
# ...

# %%
print(get_nominees("https://www.goldenglobes.com/winners-nominees/2003"))
print(get_nominees("https://www.goldenglobes.com/winners-nominees/2003?page=1"))
# Out:
# ['The Hours', 'About Schmidt', 'Gangs of New York', 'Lord of the Rings: The Two Towers, The', 'Pianist, The', 'Chicago', 'About a Boy', 'Adaptation', 'My Big Fat Greek Wedding', 'Nicholas Nickleby', 'Nicole Kidman', 'Julianne Moore', 'Meryl Streep', 'Salma Hayek', 'Diane Lane', 'Jack Nicholson', 'Adrien Brody', 'Michael Caine', 'Daniel Day-Lewis', 'Leonardo DiCaprio']
# ['Renée Zellweger', 'Catherine Zeta-Jones', 'Maggie Gyllenhaal', 'Goldie Hawn', 'Nia Vardalos', 'Richard Gere', 'Nicolas Cage', 'Kieran Culkin', 'Hugh Grant', 'Adam Sandler', 'Meryl Streep', 'Kathy Bates', 'Cameron Diaz', 'Queen Latifah', 'Susan Sarandon', 'Chris Cooper', 'Ed Harris', 'Paul Newman', 'Dennis Quaid', 'John C. Reilly']

# %%
drama = ['The Hours', 'About Schmidt', 'Gangs of New York', 'The Lord of the Rings: The Two Towers', 'The Pianist']
comedy = ['Chicago', 'About a Boy', 'Adaptation', 'My Big Fat Greek Wedding', 'Nicholas Nickleby']
actress_d = ['Nicole Kidman', 'Julianne Moore', 'Meryl Streep', 'Salma Hayek', 'Diane Lane']
actor_d = ['Jack Nicholson', 'Adrien Brody', 'Michael Caine', 'Daniel Day-Lewis', 'Leonardo DiCaprio']
actress_c = ['Renée Zellweger', 'Catherine Zeta-Jones', 'Maggie Gyllenhaal', 'Goldie Hawn', 'Nia Vardalos']
actor_c = ['Richard Gere', 'Nicolas Cage', 'Kieran Culkin', 'Hugh Grant', 'Adam Sandler']
support_actress = ['Meryl Streep', 'Kathy Bates', 'Cameron Diaz', 'Queen Latifah', 'Susan Sarandon']
support_actor = ['Chris Cooper', 'Ed Harris', 'Paul Newman', 'Dennis Quaid', 'John C. Reilly']
year = ['2003', '2003', '2003', '2003', '2003']
win = [True, False, False, False, False]
df16 = df.assign(**{'year':year, 'best_drama':drama, 'win':win,'best_comedy':comedy, 'best_actress_drama':actress_d, 'best_actor_drama': actor_d, 'best_actress_comedy':actress_c, 'best_actor_comedy':actor_c, 'best_supporting_actress':support_actress, 'best_supporting_actor':support_actor})

# %%
df16
# Out:
#    year                             best_drama               best_comedy  \
# 0  2003                              The Hours                   Chicago
# 1  2003                          About Schmidt               About a Boy
# 2  2003                      Gangs of New York                Adaptation
# 3  2003  The Lord of the Rings: The Two Towers  My Big Fat Greek Wedding
# 4  2003                            The Pianist         Nicholas Nickleby
#
#     best_actor_drama best_actor_comedy best_supporting_actor  \
# 0     Jack Nicholson      Richard Gere          Chris Cooper
# 1       Adrien Brody      Nicolas Cage             Ed Harris
# 2      Michael Caine     Kieran Culkin           Paul Newman
# 3   Daniel Day-Lewis        Hugh Grant          Dennis Quaid
# 4  Leonardo DiCaprio      Adam Sandler        John C. Reilly
#
#   best_actress_drama   best_actress_comedy best_supporting_actress    win
# 0      Nicole Kidman       Renée Zellweger            Meryl Streep   True
# ...

# %%
print(get_nominees("https://www.goldenglobes.com/winners-nominees/2002"))
print(get_nominees("https://www.goldenglobes.com/winners-nominees/2002?page=1"))
# Out:
# ['A Beautiful Mind', 'In the Bedroom', 'The Lord of the Rings: The Fellowship of the Ring', "Man Who Wasn't There, The", 'Mulholland Dr.', 'Moulin Rouge!', "Bridget Jones's Diary", 'Gosford Park', 'Legally Blonde', 'Shrek', 'Sissy Spacek', 'Halle Berry', 'Judi Dench', 'Nicole Kidman', 'Deep End, The', 'Russell Crowe', 'Denzel Washington', 'Kevin Spacey', 'Will Smith', 'Billy Bob Thornton']
# ['Nicole Kidman', 'Thora Birch', 'Cate Blanchett', 'Reese Witherspoon', 'Renée Zellweger', 'Gene Hackman', 'Hugh Jackman', 'Ewan McGregor', 'John Cameron Mitchell', 'Billy Bob Thornton', 'Jennifer Connelly', 'Helen Mirren', 'Maggie Smith', 'Marisa Tomei', 'Kate Winslet', 'Cameron Diaz', 'Jim Broadbent', 'Steve Buscemi', 'Hayden Christensen', 'Ben Kingsley', 'Jude Law', 'Jon Voight']

# %%
drama = ['A Beautiful Mind', 'In the Bedroom', 'The Lord of the Rings: The Fellowship of the Ring', "The Man Who Wasn't There", 'Mulholland Dr.', 'na']
comedy = ['Moulin Rouge!', "Bridget Jones's Diary", 'Gosford Park', 'Legally Blonde', 'Shrek', 'na']
actress_d = ['Sissy Spacek', 'Halle Berry', 'Judi Dench', 'Nicole Kidman', 'The Deep End', 'na']
actor_d = ['Russell Crowe', 'Denzel Washington', 'Kevin Spacey', 'Will Smith', 'Billy Bob Thornton', 'na']
actress_c = ['Nicole Kidman', 'Thora Birch', 'Cate Blanchett', 'Reese Witherspoon', 'Renée Zellweger', 'na']
actress_c = ['Nicole Kidman', 'Thora Birch', 'Cate Blanchett', 'Reese Witherspoon', 'Renée Zellweger', 'na']
actor_c = ['Gene Hackman', 'Hugh Jackman', 'Ewan McGregor', 'John Cameron Mitchell', 'Billy Bob Thornton', 'na']
support_actress = ['Jennifer Connelly', 'Helen Mirren', 'Maggie Smith', 'Marisa Tomei', 'Kate Winslet', 'Cameron Diaz']
support_actor = ['Jim Broadbent', 'Steve Buscemi', 'Hayden Christensen', 'Ben Kingsley', 'Jude Law', 'Jon Voight']
year = ['2002', '2002', '2002', '2002', '2002', '2002']
win = [True, False, False, False, False, False]
df17 = df.assign(**{'year':year, 'best_drama':drama, 'win':win,'best_comedy':comedy, 'best_actress_drama':actress_d, 'best_actor_drama': actor_d, 'best_actress_comedy':actress_c, 'best_actor_comedy':actor_c, 'best_supporting_actress':support_actress, 'best_supporting_actor':support_actor})

# %%
df17
# Out:
#    year                                         best_drama  \
# 0  2002                                   A Beautiful Mind
# 1  2002                                     In the Bedroom
# 2  2002  The Lord of the Rings: The Fellowship of the Ring
# 3  2002                           The Man Who Wasn't There
# 4  2002                                     Mulholland Dr.
# 5  2002                                                 na
#
#              best_comedy    best_actor_drama      best_actor_comedy  \
# 0          Moulin Rouge!       Russell Crowe           Gene Hackman
# 1  Bridget Jones's Diary   Denzel Washington           Hugh Jackman
# 2           Gosford Park        Kevin Spacey          Ewan McGregor
# 3         Legally Blonde          Will Smith  John Cameron Mitchell
# 4                  Shrek  Billy Bob Thornton     Billy Bob Thornton
# 5                     na                  na                     na
#
#   best_supporting_actor best_actress_drama best_actress_comedy  \
# ...

# %%
print(get_nominees("https://www.goldenglobes.com/winners-nominees/2001"))
print(get_nominees("https://www.goldenglobes.com/winners-nominees/2001?page=1"))
# Out:
# ['Gladiator', 'Wonder Boys', 'Billy Elliot', 'Erin Brockovich', 'Sunshine', 'Traffic', 'Almost Famous', 'Best in Show', 'Chicken Run', 'Chocolat', 'O Brother, Where Art Thou?', 'Julia Roberts', 'Joan Allen', 'Björk', 'Ellen Burstyn', 'Laura Linney', 'Tom Hanks', 'Geoffrey Rush', 'Javier Bardem', 'Russell Crowe', 'Michael Douglas']
# ['Renée Zellweger', 'Juliette Binoche', 'Brenda Blethyn', 'Sandra Bullock', 'Tracey Ullman', 'George Clooney', 'Mel Gibson', 'Jim Carrey', 'John Cusack', 'Robert De Niro', 'Kate Hudson', 'Judi Dench', 'Frances McDormand', 'Julie Walters', 'Catherine Zeta-Jones', 'Benicio del Toro', 'Jeff Bridges', 'Willem Dafoe', 'Albert Finney', 'Joaquin Phoenix']

# %%
drama = ['Gladiator', 'Wonder Boys', 'Billy Elliot', 'Erin Brockovich', 'Sunshine', 'Traffic']
comedy = ['Almost Famous', 'Best in Show', 'Chicken Run', 'Chocolat', 'O Brother, Where Art Thou?', 'na']
actress_d = ['Julia Roberts', 'Joan Allen', 'Björk', 'Ellen Burstyn', 'Laura Linney', 'na']
actor_d = ['Tom Hanks', 'Geoffrey Rush', 'Javier Bardem', 'Russell Crowe', 'Michael Douglas', 'na']
actress_c = ['Renée Zellweger', 'Juliette Binoche', 'Brenda Blethyn', 'Sandra Bullock', 'Tracey Ullman', 'na']
actor_c = ['George Clooney', 'Mel Gibson', 'Jim Carrey', 'John Cusack', 'Robert De Niro', 'na']
support_actress = ['Kate Hudson', 'Judi Dench', 'Frances McDormand', 'Julie Walters', 'Catherine Zeta-Jones', 'na']
support_actor = ['Benicio del Toro', 'Jeff Bridges', 'Willem Dafoe', 'Albert Finney', 'Joaquin Phoenix', 'na']
year = ['2001', '2001', '2001', '2001', '2001', '2001']
win = [True, False, False, False, False, False]
df18 = df.assign(**{'year':year, 'best_drama':drama, 'win':win,'best_comedy':comedy, 'best_actress_drama':actress_d, 'best_actor_drama': actor_d, 'best_actress_comedy':actress_c, 'best_actor_comedy':actor_c, 'best_supporting_actress':support_actress, 'best_supporting_actor':support_actor})

# %%
df18
# Out:
#    year       best_drama                 best_comedy best_actor_drama  \
# 0  2001        Gladiator               Almost Famous        Tom Hanks
# 1  2001      Wonder Boys                Best in Show    Geoffrey Rush
# 2  2001     Billy Elliot                 Chicken Run    Javier Bardem
# 3  2001  Erin Brockovich                    Chocolat    Russell Crowe
# 4  2001         Sunshine  O Brother, Where Art Thou?  Michael Douglas
# 5  2001          Traffic                          na               na
#
#   best_actor_comedy best_supporting_actor best_actress_drama  \
# 0    George Clooney      Benicio del Toro      Julia Roberts
# 1        Mel Gibson          Jeff Bridges         Joan Allen
# 2        Jim Carrey          Willem Dafoe              Björk
# 3       John Cusack         Albert Finney      Ellen Burstyn
# 4    Robert De Niro       Joaquin Phoenix       Laura Linney
# 5                na                    na                 na
#
# ...

# %%
print(get_nominees("https://www.goldenglobes.com/winners-nominees/2000"))
print(get_nominees("https://www.goldenglobes.com/winners-nominees/2000?page=1"))
# Out:
# ['American Beauty', 'The End of the Affair', 'Hurricane, The', 'The Insider', 'The Talented Mr. Ripley', 'Toy Story 2', 'Being John Malkovich', 'Man on the Moon', 'Notting Hill', 'Analyze This', 'Hilary Swank', 'Julianne Moore', 'Meryl Streep', 'Sigourney Weaver', 'Annette Bening', 'Denzel Washington', 'Russell Crowe', 'Matt Damon', 'Richard Farnsworth', 'Kevin Spacey']
# ['Janet McTeer', 'Reese Witherspoon', 'Julianne Moore', 'Julia Roberts', 'Sharon Stone', 'Jim Carrey', 'Robert De Niro', 'Rupert Everett', 'Hugh Grant', 'Sean Penn', 'Angelina Jolie', 'Chloë Sevigny', 'Cameron Diaz', 'Catherine Keener', 'Samantha Morton', 'Natalie Portman', 'Tom Cruise', 'Michael Caine', 'Michael Clarke Duncan', 'Jude Law', 'Haley Joel Osment']

# %%
drama = ['American Beauty', 'The End of the Affair', 'Hurricane, The', 'The Insider', 'The Talented Mr. Ripley', 'na']
comedy = ['Toy Story 2', 'Being John Malkovich', 'Man on the Moon', 'Notting Hill', 'Analyze This', 'na']
actress_d = ['Hilary Swank', 'Julianne Moore', 'Meryl Streep', 'Sigourney Weaver', 'Annette Bening', 'na']
actor_d = ['Denzel Washington', 'Russell Crowe', 'Matt Damon', 'Richard Farnsworth', 'Kevin Spacey','na']
actress_c = ['Janet McTeer', 'Reese Witherspoon', 'Julianne Moore', 'Julia Roberts', 'Sharon Stone', 'na']
actor_c = ['Jim Carrey', 'Robert De Niro', 'Rupert Everett', 'Hugh Grant', 'Sean Penn', 'na']
support_actress = ['Angelina Jolie', 'Chloë Sevigny', 'Cameron Diaz', 'Catherine Keener', 'Samantha Morton', 'Natalie Portman']
support_actor = ['Tom Cruise', 'Michael Caine', 'Michael Clarke Duncan', 'Jude Law', 'Haley Joel Osment', 'na']
year = ['2000', '2000', '2000', '2000', '2000', '2000']
win = [True, False, False, False, False, False]
df19 = df.assign(**{'year':year, 'best_drama':drama, 'win':win,'best_comedy':comedy, 'best_actress_drama':actress_d, 'best_actor_drama': actor_d, 'best_actress_comedy':actress_c, 'best_actor_comedy':actor_c, 'best_supporting_actress':support_actress, 'best_supporting_actor':support_actor})

# %%
df19
# Out:
#    year               best_drama           best_comedy    best_actor_drama  \
# 0  2000          American Beauty           Toy Story 2   Denzel Washington
# 1  2000    The End of the Affair  Being John Malkovich       Russell Crowe
# 2  2000           Hurricane, The       Man on the Moon          Matt Damon
# 3  2000              The Insider          Notting Hill  Richard Farnsworth
# 4  2000  The Talented Mr. Ripley          Analyze This        Kevin Spacey
# 5  2000                       na                    na                  na
#
#   best_actor_comedy  best_supporting_actor best_actress_drama  \
# 0        Jim Carrey             Tom Cruise       Hilary Swank
# 1    Robert De Niro          Michael Caine     Julianne Moore
# 2    Rupert Everett  Michael Clarke Duncan       Meryl Streep
# 3        Hugh Grant               Jude Law   Sigourney Weaver
# 4         Sean Penn      Haley Joel Osment     Annette Bening
# 5                na                     na                 na
#
# ...

# %%
print(get_nominees("https://www.goldenglobes.com/winners-nominees/1999"))
print(get_nominees("https://www.goldenglobes.com/winners-nominees/1999?page=1"))
# Out:
# ['Saving Private Ryan', 'Elizabeth', 'Gods and Monsters', 'Horse Whisperer, The', 'The Truman Show', 'Shakespeare in Love', 'Mask of Zorro, The', 'Patch Adams', 'Still Crazy', "There's Something About Mary", 'Bulworth', 'Cate Blanchett', 'Susan Sarandon', 'Meryl Streep', 'Emily Watson', 'Fernanda Montenegro', 'Jim Carrey', 'Stephen Fry', 'Tom Hanks', 'Ian McKellen', 'Nick Nolte']
# ['Gwyneth Paltrow', 'Cameron Diaz', 'Jane Horrocks', 'Christina Ricci', 'Meg Ryan', 'Michael Caine', 'Robin Williams', 'Antonio Banderas', 'Warren Beatty', 'John Travolta', 'Lynn Redgrave', 'Kathy Bates', 'Brenda Blethyn', 'Judi Dench', 'Sharon Stone', 'Ed Harris', 'Billy Bob Thornton', 'Robert Duvall', 'Bill Murray', 'Geoffrey Rush', 'Donald Sutherland']

# %%
drama = ['Saving Private Ryan', 'Elizabeth', 'Gods and Monsters', 'The Horse Whisperer', 'The Truman Show', 'na']
comedy = ['Shakespeare in Love', 'Mask of Zorro, The', 'Patch Adams', 'Still Crazy', "There's Something About Mary", 'Bulworth']
actress_d = ['Cate Blanchett', 'Susan Sarandon', 'Meryl Streep', 'Emily Watson', 'Fernanda Montenegro', 'na']
actor_d = ['Jim Carrey', 'Stephen Fry', 'Tom Hanks', 'Ian McKellen', 'Nick Nolte', 'na']
actress_c = ['Gwyneth Paltrow', 'Cameron Diaz', 'Jane Horrocks', 'Christina Ricci', 'Meg Ryan', 'na']
actor_c = ['Michael Caine', 'Robin Williams', 'Antonio Banderas', 'Warren Beatty', 'John Travolta', 'na']
support_actress = ['Lynn Redgrave', 'Kathy Bates', 'Brenda Blethyn', 'Judi Dench', 'Sharon Stone', 'na']
support_actor = ['Ed Harris', 'Billy Bob Thornton', 'Robert Duvall', 'Bill Murray', 'Geoffrey Rush', 'Donald Sutherland']
year = ['1999', '1999', '1999', '1999', '1999', '1999']
win = [True, False, False, False, False, False]
df20 = df.assign(**{'year':year, 'best_drama':drama, 'win':win,'best_comedy':comedy, 'best_actress_drama':actress_d, 'best_actor_drama': actor_d, 'best_actress_comedy':actress_c, 'best_actor_comedy':actor_c, 'best_supporting_actress':support_actress, 'best_supporting_actor':support_actor})

# %%
df20
# Out:
#    year           best_drama                   best_comedy best_actor_drama  \
# 0  1999  Saving Private Ryan           Shakespeare in Love       Jim Carrey
# 1  1999            Elizabeth            Mask of Zorro, The      Stephen Fry
# 2  1999    Gods and Monsters                   Patch Adams        Tom Hanks
# 3  1999  The Horse Whisperer                   Still Crazy     Ian McKellen
# 4  1999      The Truman Show  There's Something About Mary       Nick Nolte
# 5  1999                   na                      Bulworth               na
#
#   best_actor_comedy best_supporting_actor   best_actress_drama  \
# 0     Michael Caine             Ed Harris       Cate Blanchett
# 1    Robin Williams    Billy Bob Thornton       Susan Sarandon
# 2  Antonio Banderas         Robert Duvall         Meryl Streep
# 3     Warren Beatty           Bill Murray         Emily Watson
# 4     John Travolta         Geoffrey Rush  Fernanda Montenegro
# ...

# %%
print(get_nominees("https://www.goldenglobes.com/winners-nominees/1998"))
print(get_nominees("https://www.goldenglobes.com/winners-nominees/1998?page=1"))
# Out:
# ['Titanic', 'Amistad', 'Boxer, The', 'Good Will Hunting', 'L.A. Confidential', 'As Good as It Gets', 'Full Monty, The', 'Men in Black', "My Best Friend's Wedding", 'Wag the Dog', 'Judi Dench', 'Helena Bonham Carter', 'Jodie Foster', 'Jessica Lange', 'Kate Winslet', 'Peter Fonda', 'Djimon Hounsou', 'Matt Damon', 'Daniel Day-Lewis', 'Leonardo DiCaprio']
# ['Helen Hunt', 'Joey Lauren Adams', 'Pam Grier', 'Jennifer Lopez', 'Julia Roberts', 'Jack Nicholson', 'Jim Carrey', 'Dustin Hoffman', 'Samuel L. Jackson', 'Kevin Kline', 'Kim Basinger', 'Julianne Moore', 'Gloria Stuart', 'Sigourney Weaver', 'Joan Cusack', 'Burt Reynolds', 'Rupert Everett', 'Anthony Hopkins', 'Greg Kinnear', 'Jon Voight', 'Robin Williams']

# %%
drama = ['Titanic', 'Amistad', 'The Boxer', 'Good Will Hunting', 'L.A. Confidential', 'na']
comedy = ['As Good as It Gets', 'The Full Monty', 'Men in Black', "My Best Friend's Wedding", 'Wag the Dog', 'na']
actress_d = ['Judi Dench', 'Helena Bonham Carter', 'Jodie Foster', 'Jessica Lange', 'Kate Winslet', 'na']
actor_d = ['Peter Fonda', 'Djimon Hounsou', 'Matt Damon', 'Daniel Day-Lewis', 'Leonardo DiCaprio', 'na']
actress_c = ['Helen Hunt', 'Joey Lauren Adams', 'Pam Grier', 'Jennifer Lopez', 'Julia Roberts', 'na']
actor_c = ['Jack Nicholson', 'Jim Carrey', 'Dustin Hoffman', 'Samuel L. Jackson', 'Kevin Kline', 'na']
support_actress = ['Kim Basinger', 'Julianne Moore', 'Gloria Stuart', 'Sigourney Weaver', 'Joan Cusack', 'na']
support_actor = ['Burt Reynolds', 'Rupert Everett', 'Anthony Hopkins', 'Greg Kinnear', 'Jon Voight', 'Robin Williams']
year = ['1998', '1998', '1998', '1998', '1998', '1998']
win = [True, False, False, False, False, False]
df21 = df.assign(**{'year':year, 'best_drama':drama, 'win':win,'best_comedy':comedy, 'best_actress_drama':actress_d, 'best_actor_drama': actor_d, 'best_actress_comedy':actress_c, 'best_actor_comedy':actor_c, 'best_supporting_actress':support_actress, 'best_supporting_actor':support_actor})

# %%
df21
# Out:
#    year         best_drama               best_comedy   best_actor_drama  \
# 0  1998            Titanic        As Good as It Gets        Peter Fonda
# 1  1998            Amistad            The Full Monty     Djimon Hounsou
# 2  1998          The Boxer              Men in Black         Matt Damon
# 3  1998  Good Will Hunting  My Best Friend's Wedding   Daniel Day-Lewis
# 4  1998  L.A. Confidential               Wag the Dog  Leonardo DiCaprio
# 5  1998                 na                        na                 na
#
#    best_actor_comedy best_supporting_actor    best_actress_drama  \
# 0     Jack Nicholson         Burt Reynolds            Judi Dench
# 1         Jim Carrey        Rupert Everett  Helena Bonham Carter
# 2     Dustin Hoffman       Anthony Hopkins          Jodie Foster
# 3  Samuel L. Jackson          Greg Kinnear         Jessica Lange
# 4        Kevin Kline            Jon Voight          Kate Winslet
# 5                 na        Robin Williams                    na
#
# ...

# %%
print(get_nominees("https://www.goldenglobes.com/winners-nominees/1997"))
print(get_nominees("https://www.goldenglobes.com/winners-nominees/1997?page=1"))
# Out:
# ['The English Patient', 'People vs. Larry Flynt, The', 'Secrets & Lies', 'Shine', 'Breaking the Waves', 'Evita', 'Birdcage, The', 'Everyone Says I Love You', 'Fargo', 'Jerry Maguire', 'Brenda Blethyn', 'Courtney Love', 'Kristin Scott Thomas', 'Meryl Streep', 'Emily Watson', 'Geoffrey Rush', 'Ralph Fiennes', 'Mel Gibson', 'Woody Harrelson', 'Liam Neeson']
# ['Madonna', 'Barbra Streisand', 'Glenn Close', 'Frances McDormand', 'Debbie Reynolds', 'Tom Cruise', 'Antonio Banderas', 'Kevin Costner', 'Nathan Lane', 'Eddie Murphy', 'Lauren Bacall', 'Marion Ross', 'Joan Allen', 'Juliette Binoche', 'Barbara Hershey', 'Marianne Jean-Baptiste', 'Edward Norton', 'Cuba Gooding Jr.', 'Samuel L. Jackson', 'Paul Scofield', 'James Woods']

# %%
drama = ['The English Patient', 'The People vs. Larry Flynt', 'Secrets & Lies', 'Shine', 'Breaking the Waves', 'na']
comedy = ['Evita', 'The Birdcage', 'Everyone Says I Love You', 'Fargo', 'Jerry Maguire', 'na']
actress_d = ['Brenda Blethyn', 'Courtney Love', 'Kristin Scott Thomas', 'Meryl Streep', 'Emily Watson', 'na']
actor_d = ['Geoffrey Rush', 'Ralph Fiennes', 'Mel Gibson', 'Woody Harrelson', 'Liam Neeson', 'na']
actress_c = ['Madonna', 'Barbra Streisand', 'Glenn Close', 'Frances McDormand', 'Debbie Reynolds', 'na']
actor_c = ['Tom Cruise', 'Antonio Banderas', 'Kevin Costner', 'Nathan Lane', 'Eddie Murphy', 'na']
support_actress = ['Lauren Bacall', 'Marion Ross', 'Joan Allen', 'Juliette Binoche', 'Barbara Hershey', 'Marianne Jean-Baptiste']
support_actor = ['Edward Norton', 'Cuba Gooding Jr.', 'Samuel L. Jackson', 'Paul Scofield', 'James Woods', 'na']
year = ['1997', '1997', '1997', '1997', '1997', '1997']
win = [True, False, False, False, False, False]
df22 = df.assign(**{'year':year, 'best_drama':drama, 'win':win,'best_comedy':comedy, 'best_actress_drama':actress_d, 'best_actor_drama': actor_d, 'best_actress_comedy':actress_c, 'best_actor_comedy':actor_c, 'best_supporting_actress':support_actress, 'best_supporting_actor':support_actor})

# %%
df22
# Out:
#    year                  best_drama               best_comedy  \
# 0  1997         The English Patient                     Evita
# 1  1997  The People vs. Larry Flynt              The Birdcage
# 2  1997              Secrets & Lies  Everyone Says I Love You
# 3  1997                       Shine                     Fargo
# 4  1997          Breaking the Waves             Jerry Maguire
# 5  1997                          na                        na
#
#   best_actor_drama best_actor_comedy best_supporting_actor  \
# 0    Geoffrey Rush        Tom Cruise         Edward Norton
# 1    Ralph Fiennes  Antonio Banderas      Cuba Gooding Jr.
# 2       Mel Gibson     Kevin Costner     Samuel L. Jackson
# 3  Woody Harrelson       Nathan Lane         Paul Scofield
# 4      Liam Neeson      Eddie Murphy           James Woods
# 5               na                na                    na
#
#      best_actress_drama best_actress_comedy best_supporting_actress    win
# ...

# %%
print(get_nominees("https://www.goldenglobes.com/winners-nominees/1996"))
print(get_nominees("https://www.goldenglobes.com/winners-nominees/1996?page=1"))
# Out:
# ['Sense and Sensibility', 'Apollo 13', 'Braveheart', 'Bridges of Madison County, The', 'Leaving Las Vegas', 'Babe', 'American President, The', 'Get Shorty', 'Sabrina (1995)', 'Toy Story', 'Sharon Stone', 'Susan Sarandon', 'Elisabeth Shue', 'Meryl Streep', 'Emma Thompson', 'Nicolas Cage', 'Sean Penn', 'Richard Dreyfuss', 'Anthony Hopkins', 'Ian McKellen']
# ['Nicole Kidman', 'Annette Bening', 'Sandra Bullock', 'Toni Collette', 'Vanessa Redgrave', 'John Travolta', 'Harrison Ford', 'Steve Martin', 'Patrick Swayze', 'Michael Douglas', 'Mira Sorvino', 'Anjelica Huston', 'Kathleen Quinlan', 'Kyra Sedgwick', 'Kate Winslet', 'Brad Pitt', 'John Leguizamo', 'Tim Roth', 'Kevin Spacey', 'Ed Harris']

# %%
drama = ['Sense and Sensibility', 'Apollo 13', 'Braveheart', 'The Bridges of Madison County', 'Leaving Las Vegas']
comedy = ['Babe', 'The American President', 'Get Shorty', 'Sabrina', 'Toy Story']
actress_d = ['Sharon Stone', 'Susan Sarandon', 'Elisabeth Shue', 'Meryl Streep', 'Emma Thompson']
actor_d = ['Nicolas Cage', 'Sean Penn', 'Richard Dreyfuss', 'Anthony Hopkins', 'Ian McKellen']
actress_c = ['Nicole Kidman', 'Annette Bening', 'Sandra Bullock', 'Toni Collette', 'Vanessa Redgrave']
actor_c = ['John Travolta', 'Harrison Ford', 'Steve Martin', 'Patrick Swayze', 'Michael Douglas']
support_actress = ['Mira Sorvino', 'Anjelica Huston', 'Kathleen Quinlan', 'Kyra Sedgwick', 'Kate Winslet']
support_actor = ['Brad Pitt', 'John Leguizamo', 'Tim Roth', 'Kevin Spacey', 'Ed Harris']
year = ['1996', '1996', '1996', '1996', '1996']
win = [True, False, False, False, False]
df23 = df.assign(**{'year':year, 'best_drama':drama, 'win':win,'best_comedy':comedy, 'best_actress_drama':actress_d, 'best_actor_drama': actor_d, 'best_actress_comedy':actress_c, 'best_actor_comedy':actor_c, 'best_supporting_actress':support_actress, 'best_supporting_actor':support_actor})

# %%
df23
# Out:
#    year                     best_drama             best_comedy  \
# 0  1996          Sense and Sensibility                    Babe
# 1  1996                      Apollo 13  The American President
# 2  1996                     Braveheart              Get Shorty
# 3  1996  The Bridges of Madison County                 Sabrina
# 4  1996              Leaving Las Vegas               Toy Story
#
#    best_actor_drama best_actor_comedy best_supporting_actor  \
# 0      Nicolas Cage     John Travolta             Brad Pitt
# 1         Sean Penn     Harrison Ford        John Leguizamo
# 2  Richard Dreyfuss      Steve Martin              Tim Roth
# 3   Anthony Hopkins    Patrick Swayze          Kevin Spacey
# 4      Ian McKellen   Michael Douglas             Ed Harris
#
#   best_actress_drama best_actress_comedy best_supporting_actress    win
# 0       Sharon Stone       Nicole Kidman            Mira Sorvino   True
# 1     Susan Sarandon      Annette Bening         Anjelica Huston  False
# ...

# %%
print(get_nominees("https://www.goldenglobes.com/winners-nominees/1995"))
print(get_nominees("https://www.goldenglobes.com/winners-nominees/1995?page=1"))
# Out:
# ['Forrest Gump', 'Nell', 'Pulp Fiction', 'Quiz Show', 'Legends of the Fall', 'The Lion King', 'Adventures of Priscilla, Queen of the Desert, The', 'Ed Wood', 'Four Weddings and a Funeral', 'Ready to Wear', 'Jessica Lange', 'Jodie Foster', 'Jennifer Jason Leigh', 'Miranda Richardson', 'Meryl Streep', 'Tom Hanks', 'Morgan Freeman', 'Paul Newman', 'Brad Pitt', 'John Travolta']
# ['Jamie Lee Curtis', 'Geena Davis', 'Andie MacDowell', 'Shirley MacLaine', 'Emma Thompson', 'Hugh Grant', 'Terence Stamp', 'Jim Carrey', 'Johnny Depp', 'Arnold Schwarzenegger', 'Dianne Wiest', 'Kirsten Dunst', 'Sophia Loren', 'Uma Thurman', 'Robin Wright', 'Martin Landau', 'Kevin Bacon', 'Samuel L. Jackson', 'Gary Sinise', 'John Turturro']

# %%
drama = ['Forrest Gump', 'Nell', 'Pulp Fiction', 'Quiz Show', 'Legends of the Fall']
comedy = ['The Lion King', 'The Adventures of Priscilla, Queen of the Desert', 'Ed Wood', 'Four Weddings and a Funeral', 'Ready to Wear']
actress_d = ['Jessica Lange', 'Jodie Foster', 'Jennifer Jason Leigh', 'Miranda Richardson', 'Meryl Streep']
actor_d = ['Tom Hanks', 'Morgan Freeman', 'Paul Newman', 'Brad Pitt', 'John Travolta']
actress_c = ['Jamie Lee Curtis', 'Geena Davis', 'Andie MacDowell', 'Shirley MacLaine', 'Emma Thompson']
actor_c = ['Hugh Grant', 'Terence Stamp', 'Jim Carrey', 'Johnny Depp', 'Arnold Schwarzenegger']
support_actress = ['Dianne Wiest', 'Kirsten Dunst', 'Sophia Loren', 'Uma Thurman', 'Robin Wright']
support_actor = ['Martin Landau', 'Kevin Bacon', 'Samuel L. Jackson', 'Gary Sinise', 'John Turturro']
year = ['1995', '1995', '1995', '1995', '1995']
win = [True, False, False, False, False]
df24 = df.assign(**{'year':year, 'best_drama':drama, 'win':win,'best_comedy':comedy, 'best_actress_drama':actress_d, 'best_actor_drama': actor_d, 'best_actress_comedy':actress_c, 'best_actor_comedy':actor_c, 'best_supporting_actress':support_actress, 'best_supporting_actor':support_actor})

# %%
df24
# Out:
#    year           best_drama  \
# 0  1995         Forrest Gump
# 1  1995                 Nell
# 2  1995         Pulp Fiction
# 3  1995            Quiz Show
# 4  1995  Legends of the Fall
#
#                                         best_comedy best_actor_drama  \
# 0                                     The Lion King        Tom Hanks
# 1  The Adventures of Priscilla, Queen of the Desert   Morgan Freeman
# 2                                           Ed Wood      Paul Newman
# 3                       Four Weddings and a Funeral        Brad Pitt
# 4                                     Ready to Wear    John Travolta
#
#        best_actor_comedy best_supporting_actor    best_actress_drama  \
# 0             Hugh Grant         Martin Landau         Jessica Lange
# 1          Terence Stamp           Kevin Bacon          Jodie Foster
# 2             Jim Carrey     Samuel L. Jackson  Jennifer Jason Leigh
# 3            Johnny Depp           Gary Sinise    Miranda Richardson
# ...

# %%
whole_df = pd.concat([df0,df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16, df17, df18, df19, df20, df21, df22, df23, df24])

# %%
whole_df.reset_index(inplace=True)

# %%
whole_df.drop(columns='index', inplace=True)

# %%
whole_df
# Out:
#      year                                 best_drama  \
# 0    2019                          Bohemian Rhapsody
# 1    2019                              Black Panther
# 2    2019                             BlacKkKlansman
# 3    2019                 If Beale Street Could Talk
# 4    2019                             A Star Is Born
# 5    2018  Three Billboards Outside Ebbing, Missouri
# 6    2018                       Call Me By Your Name
# 7    2018                                    Dunkirk
# 8    2018                                   The Post
# 9    2018                         The Shape of Water
# 10   2017                                  Moonlight
# 11   2017                         Hell or High Water
# 12   2017                                       Lion
# 13   2017                      Manchester by the Sea
# 14   2017                              Hacksaw Ridge
# 15   2016                               The Revenant
# 16   2016                         Mad Max: Fury Road
# ...

# %%
whole_df['award'] = 'Golden Globes'

# %%
whole_df.set_index('award')
# Out:
#                year                                 best_drama  \
# award
# Golden Globes  2019                          Bohemian Rhapsody
# Golden Globes  2019                              Black Panther
# Golden Globes  2019                             BlacKkKlansman
# Golden Globes  2019                 If Beale Street Could Talk
# Golden Globes  2019                             A Star Is Born
# Golden Globes  2018  Three Billboards Outside Ebbing, Missouri
# Golden Globes  2018                       Call Me By Your Name
# Golden Globes  2018                                    Dunkirk
# Golden Globes  2018                                   The Post
# Golden Globes  2018                         The Shape of Water
# Golden Globes  2017                                  Moonlight
# Golden Globes  2017                         Hell or High Water
# Golden Globes  2017                                       Lion
# Golden Globes  2017                      Manchester by the Sea
# ...

# %%
len(whole_df)
# Out:
# 137

# %%
whole_df.to_csv('golden_globes.csv')

# %%
# will add 2020 nominees to list once the winners are awarded
